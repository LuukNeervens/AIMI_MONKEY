# %%
pip install imagecodecs
# Out:
# Collecting imagecodecs
#   Using cached imagecodecs-2025.3.30-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (45.6 MB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from imagecodecs) (1.23.5)
# Installing collected packages: imagecodecs
# Successfully installed imagecodecs-2025.3.30
#
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in c:\users\luukn\appdata\local\programs\python\python312\lib\site-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in c:\users\luukn\appdata\local\programs\python\python312\lib\site-packages (from rasterio) (2023.7.22)
# Requirement already satisfied: click>=4.0 in c:\users\luukn\appdata\local\programs\python\python312\lib\site-packages (from rasterio) (8.1.7)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\luukn\appdata\local\programs\python\python312\lib\site-packages (from rasterio) (1.26.4)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in c:\users\luukn\appdata\local\programs\python\python312\lib\site-packages (from rasterio) (3.1.1)
# Requirement already satisfied: colorama in c:\users\luukn\appdata\local\programs\python\python312\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Downloading rasterio-1.4.3-cp312-cp312-win_amd64.whl (25.4 MB)
#    ---------------------------------------- 0.0/25.4 MB ? eta -:--:--
#    --------- ------------------------------ 6.0/25.4 MB 33.7 MB/s eta 0:00:01
#    --------------------- ------------------ 13.9/25.4 MB 36.4 MB/s eta 0:00:01
#    ------------------------------- -------- 19.9/25.4 MB 34.0 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.4 MB 34.3 MB/s eta 0:00:01
#    ---------------------------------------- 25.4/25.4 MB 31.6 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: affine, cligj, click-plugins, rasterio
#
#    ---------------------------------------- 0/4 [affine]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ------------------------------ --------- 3/4 [rasterio]
#    ---------------------------------------- 4/4 [rasterio]
#
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn

# %%
import os
import re
import json
import random
from pathlib import Path
import xml.etree.ElementTree as ET
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tifffile as tiff
import openslide
import rasterio
from rasterio.windows import Window
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, ConcatDataset
from torchvision import models, transforms, datasets
from tqdm import tqdm
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from tifffile import imread
import glob

# %%
happiny_folder = Path(r"C:\Users\luukn\AIMI_MONKEY2\monkey-training")
orig_dir = happiny_folder / "images/pas-original"
cpg_dir = happiny_folder / "images/pas-cpg"
diagnostic_dir = happiny_folder / "images/pas-diagnostic"
xml_dir = happiny_folder / "annotations/xml"

# %% [markdown]
# # Extracting patches for testing

# %%
patch_size = 256
patches_per_image = 25
output_folder = Path(r"C:\Users\luukn\AIMI_MONKEY2\monkey-training\patches_newest\cpg_test")
output_folder.mkdir(parents=True, exist_ok=True)

def check_white_space(patch):
    white_threshold = 240
    black_threshold = 15
    white_pixels = np.sum(patch > white_threshold)
    black_pixels = np.sum(patch < black_threshold)
    total_pixels = patch.size
    return (white_pixels / total_pixels) > 0.95 or (black_pixels / total_pixels) > 0.95

def process_image(img_path, max_patches):
    print(f"🔄 Processing {img_path}")
    img = imread(str(img_path), maxworkers=4)

    if img.ndim == 2:
        img = np.stack([img]*3, axis=-1)
    elif img.shape[0] in [3, 4] and img.ndim == 3:
        img = np.moveaxis(img, 0, -1)

    height, width = img.shape[:2]
    print(f"Image shape: {img.shape}")

    valid_coords = []
    for y in range(0, height - patch_size + 1, patch_size):
        for x in range(0, width - patch_size + 1, patch_size):
            patch = img[y:y+patch_size, x:x+patch_size]
            if not check_white_space(patch):
                valid_coords.append((x, y))
    
    print(valid_coords)

    selected_coords = random.sample(valid_coords, min(max_patches, len(valid_coords)))

    for x, y in selected_coords:
        patch = img[y:y+patch_size, x:x+patch_size]
        patch_img = Image.fromarray(patch.astype(np.uint8))
        patch_img.save(output_folder / f"{Path(img_path).stem}_x{x}_y{y}.png")

    return len(selected_coords)

def main():
    image_paths = glob.glob(str(cpg_dir / "*.tif"))

    total_patches = 0
    for img_path in image_paths:
        count = process_image(img_path, patches_per_image)
        total_patches += count

    print(f"✅ Done. Total patches saved: {total_patches}")

main()
# Out:
# 🔄 Processing C:\Users\luukn\AIMI_MONKEY2\monkey-training\images\pas-cpg\A_P000001_PAS_CPG.tif
# Image shape: (95744, 97536, 3)
# [(20992, 1280), (34304, 4096), (34560, 4096), (34816, 4096), (35072, 4096), (41472, 4352), (23552, 4864), (23808, 4864), (24064, 4864), (24320, 4864), (24576, 4864), (24832, 4864), (25088, 4864), (22784, 5120), (23040, 5120), (23296, 5120), (23552, 5120), (23808, 5120), (24064, 5120), (24320, 5120), (24576, 5120), (24832, 5120), (25088, 5120), (25344, 5120), (25600, 5120), (25856, 5120), (26112, 5120), (26368, 5120), (26624, 5120), (22016, 5376), (22272, 5376), (22528, 5376), (22784, 5376), (23040, 5376), (23296, 5376), (23552, 5376), (23808, 5376), (24064, 5376), (24320, 5376), (24576, 5376), (24832, 5376), (25088, 5376), (25344, 5376), (25600, 5376), (25856, 5376), (26112, 5376), (26368, 5376), (26624, 5376), (26880, 5376), (27136, 5376), (27392, 5376), (27648, 5376), (22272, 5632), (22528, 5632), (22784, 5632), (23040, 5632), (23296, 5632), (23552, 5632), (23808, 5632), (24064, 5632), (24320, 5632), (24576, 5632), (24832, 5632), (25088, 5632), (25344, 5632), (25600, 5632), (25856, 5632), (26112, 5632), (26368, 5632), (26624, 5632), (26880, 5632), (27136, 5632), (27392, 5632), (27648, 5632), (27904, 5632), (22272, 5888), (22528, 5888), (22784, 5888), (23040, 5888), (23296, 5888), (23552, 5888), (23808, 5888), (24064, 5888), (24320, 5888), (24576, 5888), (24832, 5888), (25088, 5888), (25344, 5888), (25600, 5888), (25856, 5888), (26112, 5888), (26368, 5888), (26624, 5888), (26880, 5888), (27136, 5888), (27392, 5888), (27648, 5888), (27904, 5888), (28160, 5888), (28416, 5888), (28672, 5888), (28928, 5888), (29184, 5888), (22784, 6144), (23040, 6144), (23296, 6144), (23552, 6144), (23808, 6144), (24064, 6144), (24320, 6144), (24576, 6144), (24832, 6144), (25088, 6144), (25344, 6144), (25600, 6144), (25856, 6144), (26112, 6144), (26368, 6144), (26624, 6144), (26880, 6144), (27136, 6144), (27392, 6144), (27648, 6144), (27904, 6144), (28160, 6144), (28416, 6144), (28672, 6144), (28928, 6144), (29184, 6144), (29440, 6144), (29696, 6144), (15104, 6400), (22784, 6400), (23040, 6400), (23296, 6400), (23552, 6400), (23808, 6400), (24064, 6400), (24320, 6400), (24576, 6400), (24832, 6400), (25088, 6400), (25344, 6400), (25600, 6400), (25856, 6400), (26112, 6400), (26368, 6400), (26624, 6400), (26880, 6400), (27136, 6400), (27392, 6400), (27648, 6400), (27904, 6400), (28160, 6400), (28416, 6400), (28672, 6400), (28928, 6400), (29184, 6400), (29440, 6400), (29696, 6400), (29952, 6400), (30208, 6400), (30464, 6400), (30976, 6400), (23040, 6656), (23296, 6656), (23552, 6656), (23808, 6656), (24064, 6656), (24320, 6656), (24576, 6656), (24832, 6656), (25088, 6656), (25344, 6656), (25600, 6656), (25856, 6656), (26112, 6656), (26368, 6656), (26624, 6656), (26880, 6656), (27136, 6656), (27392, 6656), (27648, 6656), (27904, 6656), (28160, 6656), (28416, 6656), (28672, 6656), (28928, 6656), (29184, 6656), (29440, 6656), (29696, 6656), (29952, 6656), (30208, 6656), (30464, 6656), (30720, 6656), (30976, 6656), (23040, 6912), (23296, 6912), (23552, 6912), (23808, 6912), (24064, 6912), (24320, 6912), (24576, 6912), (24832, 6912), (25088, 6912), (25344, 6912), (25600, 6912), (25856, 6912), (26112, 6912), (26368, 6912), (26624, 6912), (26880, 6912), (27136, 6912), (27392, 6912), (27648, 6912), (27904, 6912), (28160, 6912), (28416, 6912), (28672, 6912), (28928, 6912), (29184, 6912), (29440, 6912), (29696, 6912), (29952, 6912), (30208, 6912), (30464, 6912), (30720, 6912), (30976, 6912), (31232, 6912), (31488, 6912), (31744, 6912), (54784, 6912), (23040, 7168), (23296, 7168), (23552, 7168), (23808, 7168), (24064, 7168), (24320, 7168), (24576, 7168), (24832, 7168), (25088, 7168), (25344, 7168), (25600, 7168), (25856, 7168), (26112, 7168), (26368, 7168), (26624, 7168), (26880, 7168), (27136, 7168), (27392, 7168), (27648, 7168), (27904, 7168), (28160, 7168), (28416, 7168), (28672, 7168), (28928, 7168), (29184, 7168), (29440, 7168), (29696, 7168), (29952, 7168), (30208, 7168), (30464, 7168), (30720, 7168), (30976, 7168), (31232, 7168), (31488, 7168), (31744, 7 ...
# 🔄 Processing C:\Users\luukn\AIMI_MONKEY2\monkey-training\images\pas-cpg\A_P000002_PAS_CPG.tif
# Image shape: (89600, 97536, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 54
#      50         total_patches += count
#      52     print(f"✅ Done. Total patches saved: {total_patches}")
# ---> 54 main()
#
# Cell In[9], line 49, in main()
#      47 total_patches = 0
#      48 for img_path in image_paths:
# ---> 49     count = process_image(img_path, patches_per_image)
#      50     total_patches += count
#      52 print(f"✅ Done. Total patches saved: {total_patches}")
#
# Cell In[9], line 30, in process_image(img_path, max_patches)
#      28     for x in range(0, width - patch_size + 1, patch_size):
#      29         patch = img[y:y+patch_size, x:x+patch_size]
# ---> 30         if not check_white_space(patch):
#      31             valid_coords.append((x, y))
#      33 print(valid_coords)
#
# Cell In[9], line 10, in check_white_space(patch)
#       8 black_threshold = 15
#       9 white_pixels = np.sum(patch > white_threshold)
# ---> 10 black_pixels = np.sum(patch < black_threshold)
#      11 total_pixels = patch.size
#      12 return (white_pixels / total_pixels) > 0.95 or (black_pixels / total_pixels) > 0.95
#
# File c:\Users\luukn\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File c:\Users\luukn\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# # Extracting patches from ROIs from the train dirs

# %%
PATCH_SIZE = 256
NUM_JSONS = 81
NUM_PATCHES_PER_FILE = 300

#happiny_folder = Path("/data/temporary/archives/lung/generator/MONKEY_challenge")
json_pixel_dir = happiny_folder / "annotations/json_pixel"
PATCHES_DIR = happiny_folder / "patches_newest"  
modalities = {
    "pas-original": happiny_folder / "images/pas-original",
    "pas-cpg": happiny_folder / "images/pas-cpg",
    "pas-diagnostic": happiny_folder / "images/pas-diagnostic",
}

PATCHES_DIR.mkdir(parents=True, exist_ok=True)

def get_sample_id(json_path):
    match = re.search(r'P\d{6}', json_path.name)
    return match.group(0) if match else None

def load_json_annotations(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
    return [(int(p["point"][0]), int(p["point"][1])) for p in data.get("points", [])]

def check_white_space(patch):
    white_threshold = 240  # Adjust this threshold as needed
    black_threshold = 15
    white_pixels = np.sum(patch > white_threshold)
    black_pixels = np.sum(patch < black_threshold)
    total_pixels = patch.size
    return (white_pixels / total_pixels) > 0.95 or  (black_pixels / total_pixels) > 0.95 # Adjust the ratio as needed

def extract_patch(tif_path, center_x, center_y, patch_size=PATCH_SIZE):
    half = patch_size // 2
    xmin = max(center_x - half, 0)
    ymin = max(center_y - half, 0)
    with rasterio.open(tif_path) as src:
        max_width, max_height = src.width, src.height
        xmin = min(xmin, max_width - patch_size)
        ymin = min(ymin, max_height - patch_size)
        window = Window(xmin, ymin, patch_size, patch_size)
        patch = src.read(window=window)
        patch = np.transpose(patch, (1, 2, 0))  # (H, W, C)
    return patch

def save_selected_patches():
    json_files = list(json_pixel_dir.glob("*inflammatory-cells.json"))
    print(f"🔍 Found {len(json_files)} inflammatory cell JSON files")

    # Randomly sample JSON files without replacement
    json_files_sampled = random.sample(json_files, min(NUM_JSONS, len(json_files)))

    for modality, tif_dir in modalities.items():
        output_dir = PATCHES_DIR / modality
        output_dir.mkdir(parents=True, exist_ok=True)
        print(f"\nProcessing modality: {modality}")

        for json_file in json_files_sampled:
            coords = load_json_annotations(json_file)[:NUM_PATCHES_PER_FILE]
            sample_id = get_sample_id(json_file)
            if not sample_id:
                continue

            tif_matches = list(tif_dir.glob(f"*{sample_id}*.tif"))
            if not tif_matches:
                print(f"  ⚠️ No TIFF file found for sample ID {sample_id} in {modality}")
                continue

            tif_path = tif_matches[0]  # Take the first match
            print(f"  Using {tif_path.name} with {len(coords)} ROIs")

            for i, (x, y) in enumerate(coords):
                try:
                    patch = extract_patch(tif_path, x, y, PATCH_SIZE)
                    patch_img = Image.fromarray(patch.astype(np.uint8))
                    if check_white_space(patch):
                        print(f"    ⚠️ Patch {i} at ({x},{y}) is too white or black, skipping.")
                        continue
                    else:
                        patch_name = f"{sample_id}_patch{i}.png"
                        patch_img.save(output_dir / patch_name)
                except Exception as e:
                    print(f"    ⚠️ Failed to extract patch {i} at ({x},{y}): {e}")

if __name__ == "__main__":
    save_selected_patches()
    print("\n✅ Patch extraction complete.")
# Out:
# 🔍 Found 81 inflammatory cell JSON files
#
# Processing modality: pas-original
#   ⚠️ No TIFF file found for sample ID P000035 in pas-original
#   ⚠️ No TIFF file found for sample ID P000038 in pas-original
#   ⚠️ No TIFF file found for sample ID P000032 in pas-original
#   ⚠️ No TIFF file found for sample ID P000029 in pas-original
#   ⚠️ No TIFF file found for sample ID P000037 in pas-original
#   ⚠️ No TIFF file found for sample ID P000028 in pas-original
#   Using D_P000017_PAS_Original.tif with 300 ROIs
#     ⚠️ Patch 0 at (39399,71509) is too white or black, skipping.
#     ⚠️ Patch 1 at (39409,71481) is too white or black, skipping.
#     ⚠️ Patch 2 at (39511,71515) is too white or black, skipping.
#     ⚠️ Patch 3 at (39486,71349) is too white or black, skipping.
#     ⚠️ Patch 4 at (39327,71313) is too white or black, skipping.
#     ⚠️ Patch 5 at (39812,71470) is too white or black, skipping.
#     ⚠️ Patch 6 at (39657,71141) is too white or black, skipping.
#     ⚠️ Patch 7 at (39682,71197) is too white or black, skipping.
#     ⚠️ Patch 8 at (39754,71168) is too white or black, skipping.
#     ⚠️ Patch 9 at (39308,71212) is too white or black, skipping.
#     ⚠️ Patch 10 at (39317,71194) is too white or black, skipping.
#     ⚠️ Patch 11 at (39309,71172) is too white or black, skipping.
#     ⚠️ Patch 12 at (40007,71066) is too white or black, skipping.
#     ⚠️ Patch 13 at (40043,71064) is too white or black, skipping.
#     ⚠️ Patch 14 at (40039,71043) is too white or black, skipping.
#     ⚠️ Patch 15 at (40042,70988) is too white or black, skipping.
#     ⚠️ Patch 16 at (40139,71033) is too white or black, skipping.
#     ⚠️ Patch 18 at (40180,70898) is too white or black, skipping.
#     ⚠️ Patch 21 at (40440,71201) is too white or black, skipping.
#     ⚠️ Patch 22 at (40526,71175) is too white or black, skipping.
#     ⚠️ Patch 23 at (40520,71139) is too white or black, skipping.
#     ⚠️ Patch 24 at (40472,71010) is too white or black, skipping.
#     ⚠️ Patch 25 at (40593,70986) is too white or black, skipping.
#     ⚠️ Patch 26 at (40517,70962) is too white or black, skipping.
#     ⚠️ Patch 27 at (40455,70825) is too white or black, skipping.
#     ⚠️ Patch 28 at (40852,70702) is too white or black, skipping.
#     ⚠️ Patch 29 at (40766,70619) is too white or black, skipping.
#     ⚠️ Patch 30 at (40984,70259) is too white or black, skipping.
#     ⚠️ Patch 31 at (41021,70385) is too white or black, skipping.
#     ⚠️ Patch 32 at (41397,70384) is too white or black, skipping.
#     ⚠️ Patch 34 at (40085,70296) is too white or black, skipping.
#     ⚠️ Patch 38 at (40932,70109) is too white or black, skipping.
#     ⚠️ Patch 39 at (40897,70045) is too white or black, skipping.
#     ⚠️ Patch 40 at (40963,70081) is too white or black, skipping.
#     ⚠️ Patch 41 at (40878,69993) is too white or black, skipping.
#     ⚠️ Patch 42 at (41089,70048) is too white or black, skipping.
#     ⚠️ Patch 43 at (41085,70033) is too white or black, skipping.
#     ⚠️ Patch 44 at (41175,70020) is too white or black, skipping.
#     ⚠️ Patch 45 at (41183,70005) is too white or black, skipping.
#     ⚠️ Patch 46 at (41273,69990) is too white or black, skipping.
#     ⚠️ Patch 47 at (41108,70071) is too white or black, skipping.
#     ⚠️ Patch 48 at (41145,70039) is too white or black, skipping.
#     ⚠️ Patch 49 at (41101,70026) is too white or black, skipping.
#     ⚠️ Patch 50 at (40908,70058) is too white or black, skipping.
#     ⚠️ Patch 51 at (41063,69911) is too white or black, skipping.
#     ⚠️ Patch 52 at (41081,69829) is too white or black, skipping.
#     ⚠️ Patch 53 at (41085,69841) is too white or black, skipping.
#     ⚠️ Patch 54 at (40999,69810) is too white or black, skipping.
#     ⚠️ Patch 55 at (40945,69844) is too white or black, skipping.
#     ⚠️ Patch 56 at (40919,69773) is too white or black, skipping.
#     ⚠️ Patch 57 at (40919,69756) is too white or black, skipping.
#     ⚠️ Patch 58 at (40983,69747) is too white or black, skipping.
#     ⚠️ Patch 59 at (41007,69741) is too white or black, skipping.
#     ⚠️ Patch 60 at (40950,69696) is too white or black, skipping.
#     ⚠️ Patch 61 at (41018,69698) is too white or black, skipping.
#     ⚠️ Patch 62 at (41057,69664) is too white or black, skipping.
#     ⚠️ Patch 63 at (41035,69722) is too white or black, skipping.
#     ⚠️ Patch 64 at (41035,69764) is too white or black, skipping.
#     ⚠️ Patch 65 at (40868,69635) is too white or black, skipping.
#     ⚠️ Patch 66 at (41132,69611) is too white or black, skipping.
#     ⚠️ Patch 67 at (41088,69628) is too white or black, skipping.
#     ⚠️ Patch 68 at (41009,69586) is too white or black, skipping.
#     ⚠️ Patch 69 at (40922,69572) is too white or black, skipping.
#     ⚠️ Patch 70 at (40964,69523) is too white or black, skipping.
#     ⚠️ Patch 71 at (40933,69484) is too white or black, skipping.
#     ⚠️ Patch 72 at (40540,69315) is too white or black, skipping.
#     ⚠️ Patch 73 at (40512,69388) is too white or black, skipping.
#     ⚠️ Patch 77 at (39598,69798) is too white or black, skipping.
#     ⚠️ Patch 78 at (39530,69950) is too white or black, skipping.
#     ⚠️ Patch 79 at (39368,69961) is too white or black, skipping.
#     ⚠️ Patch 80 at (39224,70183) is too white or black, skipping.
#     ⚠️ Patch 81 at (39310,70139) is too white or black, skipping.
#     ⚠️ Patch 82 at (39176,70105) is too white or black, skipping.
#     ⚠️ Patch 83 at (39148,70003) is too white or black, skipping.
#     ⚠️ Patch 84 at (39117,70190) is too white or black, skipping.
#     ⚠️ Patch 85 at (39165,70213) is too white or black, skipping.
#     ⚠️ Patch 86 at (38977,70230) is too white or black, skipping.
#     ⚠️ Patch 87 at (38912,70039) is too white or black, skipping.
#     ⚠️ Patch 88 at (39135,69844) is too white or black, skipping.
#     ⚠️ Patch 89 at (39089,69834) is too white or black, skipping.
#     ⚠️ Patch 90 at (39111,69836) is too white or black, skipping.
#     ⚠️ Patch 91 at (39708,70186) is too white or black, skipping.
#     ⚠️ Patch 92 at (39617,70190) is too white or black, skipping.
#     ⚠️ Patch 93 at (39696,70522) is too white or black, skipping.
#     ⚠️ Patch 94 at (39775,70540) is too white or black, skipping.
#     ⚠️ Patch 95 at (39790,70548) is too white or black, skipping.
#     ⚠️ Patch 96 at (39825,70544) is too white or black, skipping.
#     ⚠️ Patch 97 at (39832,70561) is too white or black, skipping.
#     ⚠️ Patch 98 at (39856,70543) is too white or black, skipping.
#     ⚠️ Patch 99 at (39831,70633) is too white or black, skipping.
#     ⚠️ Patch 100 at (39825,70615) is too white or black, skipping.
#     ⚠️ Patch 101 at (39869,70609) is too white or black, skipping.
#     ⚠️ Patch 102 at (39882,70572) is too white or black, skipping.
#     ⚠️ Patch 103 at (39902,70549) is too white or black, skipping.
#     ⚠️ Patch 104 at (39943,70701) is too white or black, skipping.
#     ⚠️ Patch 105 at (40041,70826) is too white or black, skipping.
#     ⚠️ Patch 106 at (39998,70833) is too white or black, skipping.
#     ⚠️ Patch 107 at (39869,70886) is too white or black, skipping.
#     ⚠️ Patch 108 at (39548,70929) is too white or black, skipping.
#     ⚠️ Patch 109 at (39611,70924) is too white or black, skipping.
#     ⚠️ Patch 110 at (39459,70661) is too white or black, skipping.
#     ⚠️ Patch 111 at (39538,70689) is too white or black, skipping.
#     ⚠️ Patch 112 at (39348,70495) is too white or black, skipping.
#     ⚠️ Patch 113 at (39295,70499) is too white or black, skipping.
#     ⚠️ Patch 114 at (39203,70514) is too white or black, skipping.
#     ⚠️ Patch 115 at (39270,70518) is too white or black, skipping.
#     ⚠️ Patch 116 at (39094,70396) is too white or black, skipping.
#     ⚠️ Patch 117 at (39124,70390) is too white or black, skipping.
#     ⚠️ Patch 118 at (38923,70505) is too white or black, skipping.
#     ⚠️ Patch 119 at (39051,70607) is too white or black, skipping.
#     ⚠️ Patch 120 at (39050,70635) is too white or black, skipping.
#     ⚠️ Patch 121 at (39091,70639) is too white or black, skipping.
#     ⚠️ Patch 122 at (39194,70703) is too white or black, skipping.
#     ⚠️ Patch 123 at (39095,70674) is too white or black, skipping.
#     ⚠️ Patch 124 at (38952,70598) is too white or black, skipping.
#     ⚠️ Patch 125 at (38799,70390) is too white or black, skipping.
#     ⚠️ Patch 126 at (38682,70469) is too white or black, skipping.
#     ⚠️ Patch 127 at (38612,70632) is too white or black, skipping.
#     ⚠️ Patch 128 at (39255,70884) is too white or black, skipping.
#     ⚠️ Patch 130 at (41659,70172) is too white or black, skipping.
#     ⚠️ Patch 131 at (41655,70161) is too white or black, skipping.
#     ⚠️ Patch 132 at (40205,69835) is too white or black, skipping.
#     ⚠️ Patch 133 at (40135,71076) is too white or black, skipping.
#     ⚠️ Patch 134 at (39964,70927) is too white or black, skipping.
#     ⚠️ Patch 135 at (38706,71396) is too white or black, skipping.
#     ⚠️ Patch 136 at (38791,71389) is too white or black, skipping.
#     ⚠️ Patch 137 at (38810,71314) is too white or black, skipping.
#     ⚠️ Patch 138 at (39320,71548) is too white or black, skipping.
#     ⚠️ Patch 139 at (39313,71505) is too white or black, skipping.
#     ⚠️ Patch 140 at (39287,71380) is too white or black, skipping.
#     ⚠️ Patch 141 at (39316,71334) is too white or black, skipping.
#     ⚠️ Patch 142 at (39432,71395) is too white or black, skipping.
#     ⚠️ Patch 143 at (39512,71392) is too white or black, skipping.
#     ⚠️ Patch 144 at (39331,71256) is too white or black, skipping.
#     ⚠️ Patch 145 at (39313,71237) is too white or black, skipping.
#     ⚠️ Patch 146 at (39340,71198) is too white or black, skipping.
#     ⚠️ Patch 147 at (39272,71107) is too white or black, skipping.
#     ⚠️ Patch 148 at (39244,70937) is too white or black, skipping.
#     ⚠️ Patch 149 at (39248,70914) is too white or black, skipping.
#     ⚠️ Patch 150 at (39180,70854) is too white or black, skipping.
#     ⚠️ Patch 151 at (39166,70796) is too white or black, skipping.
#     ⚠️ Patch 152 at (39182,70786) is too white or black, skipping.
#     ⚠️ Patch 153 at (39077,70680) is too white or black, skipping.
#     ⚠️ Patch 154 at (39040,70672) is too white or black, skipping.
#     ⚠️ Patch 155 at (39111,70652) is too white or black, skipping.
#     ⚠️ Patch 156 at (39086,70613) is too white or black, skipping.
#     ⚠️ Patch 157 at (39104,70612) is too white or black, skipping.
#     ⚠️ Patch 158 at (38889,70631) is too white or black, skipping.
#     ⚠️ Patch 159 at (39023,70619) is too white or black, skipping.
#     ⚠️ Patch 160 at (38832,70540) is too white or black, skipping.
#     ⚠️ Patch 161 at (38853,70557) is too white or black, skipping.
#     ⚠️ Patch 162 at (38975,70555) is too white or black, skipping.
#     ⚠️ Patch 163 at (38920,70586) is too white or black, skipping.
#     ⚠️ Patch 164 at (38971,70502) is too white or black, skipping.
#     ⚠️ Patch 165 at (38990,70509) is too white or black, skipping.
#     ⚠️ Patch 166 at (38877,70492) is too white or black, skipping.
#     ⚠️ Patch 167 at (38890,70483) is too white or black, skipping.
#     ⚠️ Patch 168 at (38510,70598) is too white or black, skipping.
#     ⚠️ Patch 169 at (38589,70599) is too white or black, skipping.
#     ⚠️ Patch 170 at (38705,70589) is too white or black, skipping.
#     ⚠️ Patch 171 at (38682,70587) is too white or black, skipping.
#     ⚠️ Patch 172 at (38667,70493) is too white or black, skipping.
#     ⚠️ Patch 173 at (38646,70424) is too white or black, skipping.
#     ⚠️ Patch 174 at (38674,70409) is too white or black, skipping.
#     ⚠️ Patch 175 at (38677,70376) is too white or black, skipping.
#     ⚠️ Patch 176 at (38740,70470) is too white or black, skipping.
#     ⚠️ Patch 177 at (39017,70448) is too white or black, skipping.
#     ⚠️ Patch 178 at (39136,70458) is too white or black, skipping.
#     ⚠️ Patch 179 at (39139,70476) is too white or black, skipping.
#     ⚠️ Patch 180 at (39174,70431) is too white or black, skipping.
#     ⚠️ Patch 181 at (39285,70437) is too white or black, skipping.
#     ⚠️ Patch 182 at (39345,70422) is too white or black, skipping.
#     ⚠️ Patch 183 at (39340,70369) is too white or black, skipping.
#     ⚠️ Patch 184 at (39222,70407) is too white or black, skipping.
#     ⚠️ Patch 185 at (39233,70308) is too white or black, skipping.
#     ⚠️ Patch 186 at (39037,70364) is too white or black, skipping.
#     ⚠️ Patch 187 at (39035,70293) is too white or black, skipping.
#     ⚠️ Patch 188 at (39071,70309) is too white or black, skipping.
#     ⚠️ Patch 189 at (39356,70325) is too white or black, skipping.
#     ⚠️ Patch 190 at (39343,70317) is too white or black, skipping.
#     ⚠️ Patch 191 at (39149,70218) is too white or black, skipping.
#     ⚠️ Patch 192 at (39141,70228) is too white or black, skipping.
#     ⚠️ Patch 193 at (39189,70250) is too white or black, skipping.
#     ⚠️ Patch 194 at (39199,70270) is too white or black, skipping.
#     ⚠️ Patch 195 at (39262,70237) is too white or black, skipping.
#     ⚠️ Patch 196 at (39339,70187) is too white or black, skipping.
#     ⚠️ Patch 197 at (39325,70164) is too white or black, skipping.
#     ⚠️ Patch 198 at (38918,70085) is too white or black, skipping.
#     ⚠️ Patch 199 at (38953,70128) is too white or black, skipping.
#     ⚠️ Patch 200 at (38948,70109) is too white or black, skipping.
#     ⚠️ Patch 201 at (38956,70072) is too white or black, skipping.
#     ⚠️ Patch 202 at (39016,70086) is too white or black, skipping.
#     ⚠️ Patch 203 at (38920,69999) is too white or black, skipping.
#     ⚠️ Patch 204 at (38917,69979) is too white or black, skipping.
#     ⚠️ Patch 205 at (38945,70036) is too white or black, skipping.
#     ⚠️ Patch 206 at (39050,69985) is too white or black, skipping.
#     ⚠️ Patch 207 at (39078,70024) is too white or black, skipping.
#     ⚠️ Patch 208 at (39096,70039) is too white or black, skipping.
#     ⚠️ Patch 209 at (39142,70069) is too white or black, skipping.
#     ⚠️ Patch 210 at (39244,70006) is too white or black, skipping.
#     ⚠️ Patch 211 at (39267,70012) is too white or black, skipping.
#     ⚠️ Patch 212 at (39357,69989) is too white or black, skipping.
#     ⚠️ Patch 213 at (39364,69901) is too white or black, skipping.
#     ⚠️ Patch 214 at (39239,70034) is too white or black, skipping.
#     ⚠️ Patch 215 at (39216,69893) is too white or black, skipping.
#     ⚠️ Patch 216 at (39166,69897) is too white or black, skipping.
#     ⚠️ Patch 217 at (39307,69835) is too white or black, skipping.
#     ⚠️ Patch 218 at (39349,69810) is too white or black, skipping.
#     ⚠️ Patch 219 at (39369,69839) is too white or black, skipping.
#     ⚠️ Patch 220 at (39418,69779) is too white or black, skipping.
#     ⚠️ Patch 221 at (39006,69917) is too white or black, skipping.
#     ⚠️ Patch 222 at (39073,69873) is too white or black, skipping.
#     ⚠️ Patch 223 at (39093,69851) is too white or black, skipping.
#     ⚠️ Patch 224 at (38964,69850) is too white or black, skipping.
#     ⚠️ Patch 225 at (38988,69778) is too white or black, skipping.
#     ⚠️ Patch 226 at (38727,69664) is too white or black, skipping.
#     ⚠️ Patch 227 at (38747,69711) is too white or black, skipping.
#     ⚠️ Patch 228 at (38948,69414) is too white or black, skipping.
#     ⚠️ Patch 229 at (39001,69529) is too white or black, skipping.
#     ⚠️ Patch 230 at (39015,69547) is too white or black, skipping.
#     ⚠️ Patch 231 at (39021,69531) is too white or black, skipping.
#     ⚠️ Patch 232 at (39014,69468) is too white or black, skipping.
#     ⚠️ Patch 233 at (39043,69460) is too white or black, skipping.
#     ⚠️ Patch 234 at (39199,69584) is too white or black, skipping.
#     ⚠️ Patch 235 at (39199,69543) is too white or black, skipping.
#     ⚠️ Patch 236 at (39212,69514) is too white or black, skipping.
#     ⚠️ Patch 237 at (39426,69433) is too white or black, skipping.
#     ⚠️ Patch 238 at (39667,71432) is too white or black, skipping.
#     ⚠️ Patch 239 at (39766,71376) is too white or black, skipping.
#     ⚠️ Patch 240 at (39726,71483) is too white or black, skipping.
#     ⚠️ Patch 241 at (39736,71370) is too white or black, skipping.
#     ⚠️ Patch 242 at (39788,71308) is too white or black, skipping.
#     ⚠️ Patch 243 at (39757,71310) is too white or black, skipping.
#     ⚠️ Patch 244 at (39703,71305) is too white or black, skipping.
#     ⚠️ Patch 245 at (39656,71334) is too white or black, skipping.
#     ⚠️ Patch 246 at (39443,71146) is too white or black, skipping.
#     ⚠️ Patch 247 at (39539,71208) is too white or black, skipping.
#     ⚠️ Patch 248 at (39558,71236) is too white or black, skipping.
#     ⚠️ Patch 249 at (39523,71185) is too white or black, skipping.
#     ⚠️ Patch 250 at (39597,71180) is too white or black, skipping.
#     ⚠️ Patch 251 at (39617,71209) is too white or black, skipping.
#     ⚠️ Patch 252 at (39632,71154) is too white or black, skipping.
#     ⚠️ Patch 253 at (39743,71130) is too white or black, skipping.
#     ⚠️ Patch 254 at (39788,71187) is too white or black, skipping.
#     ⚠️ Patch 255 at (39800,71173) is too white or black, skipping.
#     ⚠️ Patch 256 at (39920,71119) is too white or black, skipping.
#     ⚠️ Patch 257 at (39968,71136) is too white or black, skipping.
#     ⚠️ Patch 259 at (40107,71246) is too white or black, skipping.
#     ⚠️ Patch 260 at (40093,71226) is too white or black, skipping.
#     ⚠️ Patch 263 at (40186,71122) is too white or black, skipping.
#     ⚠️ Patch 267 at (40669,71165) is too white or black, skipping.
#     ⚠️ Patch 268 at (40569,71181) is too white or black, skipping.
#     ⚠️ Patch 269 at (40579,71099) is too white or black, skipping.
#     ⚠️ Patch 270 at (40611,71089) is too white or black, skipping.
#     ⚠️ Patch 271 at (40549,71077) is too white or black, skipping.
#     ⚠️ Patch 272 at (40106,70954) is too white or black, skipping.
#     ⚠️ Patch 274 at (40452,70986) is too white or black, skipping.
#     ⚠️ Patch 280 at (40495,70905) is too white or black, skipping.
#     ⚠️ Patch 281 at (40476,70828) is too white or black, skipping.
#     ⚠️ Patch 282 at (40440,70845) is too white or black, skipping.
#     ⚠️ Patch 288 at (40455,70734) is too white or black, skipping.
#     ⚠️ Patch 290 at (40473,70706) is too white or black, skipping.
#     ⚠️ Patch 291 at (40519,70737) is too white or black, skipping.
#     ⚠️ Patch 292 at (40909,71070) is too white or black, skipping.
#     ⚠️ Patch 293 at (40572,70963) is too white or black, skipping.
#     ⚠️ Patch 294 at (40558,70957) is too white or black, skipping.
#     ⚠️ Patch 295 at (40629,70933) is too white or black, skipping.
#     ⚠️ Patch 296 at (40645,70899) is too white or black, skipping.
#     ⚠️ Patch 297 at (40684,70843) is too white or black, skipping.
#     ⚠️ Patch 298 at (40665,70841) is too white or black, skipping.
#     ⚠️ Patch 299 at (40695,70778) is too white or black, skipping.
#   ⚠️ No TIFF file found for sample ID P000030 in pas-original
#   Using D_P000013_PAS_Original.tif with 300 ROIs
#     ⚠️ Patch 13 at (21486,55107) is too white or black, skipping.
#     ⚠️ Patch 14 at (21498,55089) is too white or black, skipping.
#     ⚠️ Patch 15 at (21573,55079) is too white or black, skipping.
#     ⚠️ Patch 16 at (21592,55163) is too white or black, skipping.
#     ⚠️ Patch 19 at (21378,54480) is too white or black, skipping.
#     ⚠️ Patch 20 at (21722,54865) is too white or black, skipping.
#     ⚠️ Patch 21 at (21804,54847) is too white or black, skipping.
#     ⚠️ Patch 22 at (21955,54707) is too white or black, skipping.
#     ⚠️ Patch 23 at (21964,54804) is too white or black, skipping.
#     ⚠️ Patch 24 at (22096,54802) is too white or black, skipping.
#     ⚠️ Patch 25 at (22131,54774) is too white or black, skipping.
#     ⚠️ Patch 26 at (22080,54616) is too white or black, skipping.
#     ⚠️ Patch 27 at (22131,54629) is too white or black, skipping.
#     ⚠️ Patch 28 at (22082,54562) is too white or black, skipping.
#     ⚠️ Patch 29 at (21866,54507) is too white or black, skipping.
#     ⚠️ Patch 30 at (21866,54543) is too white or black, skipping.
#     ⚠️ Patch 31 at (21811,54258) is too white or black, skipping.
#     ⚠️ Patch 32 at (21822,54061) is too white or black, skipping.
#     ⚠️ Patch 33 at (21756,54120) is too white or black, skipping.
#     ⚠️ Patch 34 at (21963,54098) is too white or black, skipping.
#     ⚠️ Patch 35 at (22085,54236) is too white or black, skipping.
#     ⚠️ Patch 36 at (22535,54281) is too white or black, skipping.
#     ⚠️ Patch 37 at (22545,54430) is too white or black, skipping.
#     ⚠️ Patch 38 at (22657,54622) is too white or black, skipping.
#     ⚠️ Patch 39 at (22722,54284) is too white or black, skipping.
#     ⚠️ Patch 40 at (22742,54297) is too white or black, skipping.
#     ⚠️ Patch 41 at (22676,54372) is too white or black, skipping.
#     ⚠️ Patch 42 at (22590,54344) is too white or black, skipping.
#     ⚠️ Patch 43 at (22851,54729) is too white or black, skipping.
#     ⚠️ Patch 44 at (22747,54819) is too white or black, skipping.
#     ⚠️ Patch 45 at (22574,54892) is too white or black, skipping.
#     ⚠️ Patch 46 at (22660,54923) is too white or black, skipping.
#     ⚠️ Patch 47 at (22791,54989) is too white or black, skipping.
#     ⚠️ Patch 48 at (22788,55022) is too white or black, skipping.
#     ⚠️ Patch 49 at (22852,55105) is too white or black, skipping.
#     ⚠️ Patch 50 at (22470,55168) is too white or black, skipping.
#     ⚠️ Patch 51 at (22500,55095) is too white or black, skipping.
#     ⚠️ Patch 70 at (23025,55027) is too white or black, skipping.
#     ⚠️ Patch 71 at (23115,54973) is too white or black, skipping.
#     ⚠️ Patch 72 at (23263,54871) is too white or black, skipping.
#     ⚠️ Patch 73 at (23223,55099) is too white or black, skipping.
#     ⚠️ Patch 74 at (23002,54452) is too white or black, skipping.
#     ⚠️ Patch 75 at (23025,54332) is too white or black, skipping.
#     ⚠️ Patch 76 at (23002,54331) is too white or black, skipping.
#     ⚠️ Patch 77 at (23038,54214) is too white or black, skipping.
#     ⚠️ Patch 78 at (23076,54090) is too white or black, skipping.
#     ⚠️ Patch 79 at (22987,54038) is too white or black, skipping.
#     ⚠️ Patch 80 at (22688,53955) is too white or black, skipping.
#     ⚠️ Patch 81 at (22482,54014) is too white or black, skipping.
#     ⚠️ Patch 82 at (22680,53598) is too white or black, skipping.
#     ⚠️ Patch 83 at (23391,53625) is too white or black, skipping.
#     ⚠️ Patch 84 at (23364,53765) is too white or black, skipping.
#     ⚠️ Patch 85 at (23232,53921) is too white or black, skipping.
#     ⚠️ Patch 86 at (23638,53747) is too white or black, skipping.
#     ⚠️ Patch 87 at (23644,53859) is too white or black, skipping.
#     ⚠️ Patch 88 at (23551,53987) is too white or black, skipping.
#     ⚠️ Patch 89 at (23579,54034) is too white or black, skipping.
#     ⚠️ Patch 90 at (23587,54044) is too white or black, skipping.
#     ⚠️ Patch 91 at (23599,54099) is too white or black, skipping.
#     ⚠️ Patch 92 at (23658,54158) is too white or black, skipping.
#     ⚠️ Patch 93 at (23686,54150) is too white or black, skipping.
#     ⚠️ Patch 94 at (23754,54162) is too white or black, skipping.
#     ⚠️ Patch 95 at (23651,54209) is too white or black, skipping.
#     ⚠️ Patch 96 at (23683,54233) is too white or black, skipping.
#     ⚠️ Patch 97 at (23672,54275) is too white or black, skipping.
#     ⚠️ Patch 98 at (23486,54183) is too white or black, skipping.
#     ⚠️ Patch 99 at (23409,54137) is too white or black, skipping.
#     ⚠️ Patch 100 at (23787,54513) is too white or black, skipping.
#     ⚠️ Patch 101 at (23796,54466) is too white or black, skipping.
#     ⚠️ Patch 102 at (23665,54373) is too white or black, skipping.
#     ⚠️ Patch 103 at (23421,54431) is too white or black, skipping.
#     ⚠️ Patch 104 at (23443,54304) is too white or black, skipping.
#     ⚠️ Patch 105 at (23712,54965) is too white or black, skipping.
#     ⚠️ Patch 106 at (23644,54908) is too white or black, skipping.
#     ⚠️ Patch 107 at (23604,54836) is too white or black, skipping.
#     ⚠️ Patch 108 at (23883,55161) is too white or black, skipping.
#     ⚠️ Patch 118 at (21439,54991) is too white or black, skipping.
#     ⚠️ Patch 119 at (21947,54795) is too white or black, skipping.
#     ⚠️ Patch 120 at (22095,54431) is too white or black, skipping.
#     ⚠️ Patch 121 at (23659,54143) is too white or black, skipping.
#     ⚠️ Patch 122 at (23981,54336) is too white or black, skipping.
#     ⚠️ Patch 123 at (23702,54292) is too white or black, skipping.
#     ⚠️ Patch 124 at (23522,54225) is too white or black, skipping.
#     ⚠️ Patch 125 at (23497,54289) is too white or black, skipping.
#     ⚠️ Patch 126 at (23405,55140) is too white or black, skipping.
#     ⚠️ Patch 127 at (23379,55213) is too white or black, skipping.
#     ⚠️ Patch 128 at (23908,55276) is too white or black, skipping.
#     ⚠️ Patch 129 at (23594,55046) is too white or black, skipping.
#     ⚠️ Patch 130 at (23597,55056) is too white or black, skipping.
#     ⚠️ Patch 131 at (23442,55011) is too white or black, skipping.
#     ⚠️ Patch 138 at (22803,54917) is too white or black, skipping.
#     ⚠️ Patch 139 at (22858,54849) is too white or black, skipping.
#     ⚠️ Patch 140 at (22857,54811) is too white or black, skipping.
#     ⚠️ Patch 141 at (23865,53955) is too white or black, skipping.
#     ⚠️ Patch 142 at (22077,53631) is too white or black, skipping.
#     ⚠️ Patch 143 at (21794,53676) is too white or black, skipping.
#     ⚠️ Patch 144 at (21780,53833) is too white or black, skipping.
#     ⚠️ Patch 159 at (21647,55141) is too white or black, skipping.
#     ⚠️ Patch 160 at (21617,55183) is too white or black, skipping.
#     ⚠️ Patch 162 at (21527,55033) is too white or black, skipping.
#     ⚠️ Patch 163 at (21591,55036) is too white or black, skipping.
#     ⚠️ Patch 165 at (21453,54957) is too white or black, skipping.
#     ⚠️ Patch 166 at (21364,54939) is too white or black, skipping.
#     ⚠️ Patch 167 at (21343,54824) is too white or black, skipping.
#     ⚠️ Patch 168 at (22029,54967) is too white or black, skipping.
#     ⚠️ Patch 169 at (21962,54771) is too white or black, skipping.
#     ⚠️ Patch 170 at (22035,54640) is too white or black, skipping.
#     ⚠️ Patch 171 at (22088,54645) is too white or black, skipping.
#     ⚠️ Patch 172 at (21980,54628) is too white or black, skipping.
#     ⚠️ Patch 173 at (21205,54548) is too white or black, skipping.
#     ⚠️ Patch 174 at (21306,54526) is too white or black, skipping.
#     ⚠️ Patch 175 at (21289,54548) is too white or black, skipping.
#     ⚠️ Patch 176 at (22112,54379) is too white or black, skipping.
#     ⚠️ Patch 177 at (22107,54335) is too white or black, skipping.
#     ⚠️ Patch 178 at (21791,54228) is too white or black, skipping.
#     ⚠️ Patch 179 at (21841,54380) is too white or black, skipping.
#     ⚠️ Patch 180 at (21724,54461) is too white or black, skipping.
#     ⚠️ Patch 181 at (21362,54354) is too white or black, skipping.
#     ⚠️ Patch 182 at (21809,54057) is too white or black, skipping.
#     ⚠️ Patch 183 at (22486,53764) is too white or black, skipping.
#     ⚠️ Patch 184 at (22311,53791) is too white or black, skipping.
#     ⚠️ Patch 185 at (22129,53757) is too white or black, skipping.
#     ⚠️ Patch 186 at (22776,53497) is too white or black, skipping.
#     ⚠️ Patch 187 at (22662,53522) is too white or black, skipping.
#     ⚠️ Patch 188 at (22757,53566) is too white or black, skipping.
#     ⚠️ Patch 189 at (22790,53625) is too white or black, skipping.
#     ⚠️ Patch 190 at (22766,53666) is too white or black, skipping.
#     ⚠️ Patch 191 at (22723,53677) is too white or black, skipping.
#     ⚠️ Patch 192 at (22673,53578) is too white or black, skipping.
#     ⚠️ Patch 193 at (22703,53614) is too white or black, skipping.
#     ⚠️ Patch 194 at (22634,53597) is too white or black, skipping.
#     ⚠️ Patch 195 at (22655,53644) is too white or black, skipping.
#     ⚠️ Patch 196 at (22695,53698) is too white or black, skipping.
#     ⚠️ Patch 197 at (22683,53743) is too white or black, skipping.
#     ⚠️ Patch 198 at (22621,53800) is too white or black, skipping.
#     ⚠️ Patch 199 at (22638,53769) is too white or black, skipping.
#     ⚠️ Patch 200 at (22654,53892) is too white or black, skipping.
#     ⚠️ Patch 201 at (22934,54089) is too white or black, skipping.
#     ⚠️ Patch 202 at (22883,53844) is too white or black, skipping.
#     ⚠️ Patch 203 at (22961,53809) is too white or black, skipping.
#     ⚠️ Patch 204 at (22995,53813) is too white or black, skipping.
#     ⚠️ Patch 205 at (23011,53807) is too white or black, skipping.
#     ⚠️ Patch 206 at (23055,53833) is too white or black, skipping.
#     ⚠️ Patch 207 at (22999,53747) is too white or black, skipping.
#     ⚠️ Patch 208 at (23043,53749) is too white or black, skipping.
#     ⚠️ Patch 209 at (23049,53733) is too white or black, skipping.
#     ⚠️ Patch 210 at (23009,53643) is too white or black, skipping.
#     ⚠️ Patch 211 at (23494,53676) is too white or black, skipping.
#     ⚠️ Patch 212 at (23635,53801) is too white or black, skipping.
#     ⚠️ Patch 213 at (23806,53905) is too white or black, skipping.
#     ⚠️ Patch 214 at (23788,53955) is too white or black, skipping.
#     ⚠️ Patch 215 at (23598,53946) is too white or black, skipping.
#     ⚠️ Patch 216 at (23622,53937) is too white or black, skipping.
#     ⚠️ Patch 217 at (23664,53962) is too white or black, skipping.
#     ⚠️ Patch 218 at (23688,53918) is too white or black, skipping.
#     ⚠️ Patch 219 at (23580,54106) is too white or black, skipping.
#     ⚠️ Patch 220 at (23622,54122) is too white or black, skipping.
#     ⚠️ Patch 221 at (23615,54074) is too white or black, skipping.
#     ⚠️ Patch 222 at (23644,54049) is too white or black, skipping.
#     ⚠️ Patch 223 at (23658,54071) is too white or black, skipping.
#     ⚠️ Patch 224 at (23676,54134) is too white or black, skipping.
#     ⚠️ Patch 225 at (23784,54167) is too white or black, skipping.
#     ⚠️ Patch 226 at (23762,54178) is too white or black, skipping.
#     ⚠️ Patch 227 at (23796,54157) is too white or black, skipping.
#     ⚠️ Patch 228 at (23899,54126) is too white or black, skipping.
#     ⚠️ Patch 229 at (23773,53994) is too white or black, skipping.
#     ⚠️ Patch 230 at (23999,54305) is too white or black, skipping.
#     ⚠️ Patch 231 at (24033,54412) is too white or black, skipping.
#     ⚠️ Patch 232 at (24031,54365) is too white or black, skipping.
#     ⚠️ Patch 233 at (23930,54317) is too white or black, skipping.
#     ⚠️ Patch 234 at (23856,54394) is too white or black, skipping.
#     ⚠️ Patch 235 at (23892,54446) is too white or black, skipping.
#     ⚠️ Patch 236 at (23939,54569) is too white or black, skipping.
#     ⚠️ Patch 237 at (23667,54354) is too white or black, skipping.
#     ⚠️ Patch 238 at (23659,54336) is too white or black, skipping.
#     ⚠️ Patch 239 at (23635,54301) is too white or black, skipping.
#     ⚠️ Patch 240 at (23665,54301) is too white or black, skipping.
#     ⚠️ Patch 241 at (23720,54253) is too white or black, skipping.
#     ⚠️ Patch 242 at (23698,54275) is too white or black, skipping.
#     ⚠️ Patch 243 at (23730,54221) is too white or black, skipping.
#     ⚠️ Patch 244 at (23631,54360) is too white or black, skipping.
#     ⚠️ Patch 245 at (23576,54305) is too white or black, skipping.
#     ⚠️ Patch 246 at (23578,54496) is too white or black, skipping.
#     ⚠️ Patch 247 at (23572,54509) is too white or black, skipping.
#     ⚠️ Patch 248 at (23583,54446) is too white or black, skipping.
#     ⚠️ Patch 249 at (23508,54474) is too white or black, skipping.
#     ⚠️ Patch 250 at (23508,54451) is too white or black, skipping.
#     ⚠️ Patch 251 at (23484,54406) is too white or black, skipping.
#     ⚠️ Patch 252 at (23520,54186) is too white or black, skipping.
#     ⚠️ Patch 253 at (23520,54201) is too white or black, skipping.
#     ⚠️ Patch 254 at (23429,54471) is too white or black, skipping.
#     ⚠️ Patch 255 at (23370,54524) is too white or black, skipping.
#     ⚠️ Patch 256 at (23665,54554) is too white or black, skipping.
#     ⚠️ Patch 257 at (23658,54577) is too white or black, skipping.
#     ⚠️ Patch 258 at (23628,54619) is too white or black, skipping.
#     ⚠️ Patch 259 at (23606,54641) is too white or black, skipping.
#     ⚠️ Patch 260 at (23555,54669) is too white or black, skipping.
#     ⚠️ Patch 261 at (23589,54715) is too white or black, skipping.
#     ⚠️ Patch 262 at (23234,54460) is too white or black, skipping.
#     ⚠️ Patch 263 at (23242,54444) is too white or black, skipping.
#     ⚠️ Patch 264 at (23260,54496) is too white or black, skipping.
#     ⚠️ Patch 265 at (23279,54569) is too white or black, skipping.
#     ⚠️ Patch 266 at (23295,54552) is too white or black, skipping.
#     ⚠️ Patch 267 at (23247,54659) is too white or black, skipping.
#     ⚠️ Patch 268 at (23127,54647) is too white or black, skipping.
#     ⚠️ Patch 269 at (23175,54667) is too white or black, skipping.
#     ⚠️ Patch 270 at (23139,54696) is too white or black, skipping.
#     ⚠️ Patch 271 at (23148,54685) is too white or black, skipping.
#     ⚠️ Patch 272 at (23289,54782) is too white or black, skipping.
#     ⚠️ Patch 273 at (23301,54743) is too white or black, skipping.
#     ⚠️ Patch 274 at (23327,54747) is too white or black, skipping.
#     ⚠️ Patch 275 at (23325,54853) is too white or black, skipping.
#     ⚠️ Patch 276 at (24003,54862) is too white or black, skipping.
#     ⚠️ Patch 277 at (24001,54888) is too white or black, skipping.
#     ⚠️ Patch 278 at (24003,54776) is too white or black, skipping.
#     ⚠️ Patch 279 at (23968,54706) is too white or black, skipping.
#     ⚠️ Patch 280 at (23684,54730) is too white or black, skipping.
#     ⚠️ Patch 281 at (23686,54747) is too white or black, skipping.
#     ⚠️ Patch 282 at (23578,54792) is too white or black, skipping.
#     ⚠️ Patch 283 at (23588,54781) is too white or black, skipping.
#     ⚠️ Patch 284 at (23731,54843) is too white or black, skipping.
#     ⚠️ Patch 285 at (23658,54893) is too white or black, skipping.
#     ⚠️ Patch 286 at (23563,54893) is too white or black, skipping.
#     ⚠️ Patch 287 at (23570,54874) is too white or black, skipping.
#     ⚠️ Patch 288 at (23481,55141) is too white or black, skipping.
#     ⚠️ Patch 289 at (23518,55133) is too white or black, skipping.
#     ⚠️ Patch 290 at (23539,55161) is too white or black, skipping.
#     ⚠️ Patch 291 at (23611,55200) is too white or black, skipping.
#     ⚠️ Patch 292 at (23845,55100) is too white or black, skipping.
#     ⚠️ Patch 293 at (23780,54976) is too white or black, skipping.
#     ⚠️ Patch 294 at (23765,54936) is too white or black, skipping.
#     ⚠️ Patch 299 at (23417,55285) is too white or black, skipping.
#   Using D_P000006_PAS_Original.tif with 213 ROIs
#   ⚠️ No TIFF file found for sample ID P000039 in pas-original
#   Using D_P000011_PAS_Original.tif with 300 ROIs
#   Using D_P000004_PAS_Original.tif with 200 ROIs
#   Using D_P000016_PAS_Original.tif with 140 ROIs
#   ⚠️ No TIFF file found for sample ID P000038 in pas-original
#   ⚠️ No TIFF file found for sample ID P000022 in pas-original
#   Using D_P000013_PAS_Original.tif with 300 ROIs
#   Using D_P000010_PAS_Original.tif with 300 ROIs
#   Using D_P000014_PAS_Original.tif with 300 ROIs
#   ⚠️ No TIFF file found for sample ID P000036 in pas-original
#   Using D_P000004_PAS_Original.tif with 300 ROIs
#     ⚠️ Patch 0 at (71248,55313) is too white or black, skipping.
#     ⚠️ Patch 1 at (71024,55313) is too white or black, skipping.
#     ⚠️ Patch 2 at (71482,55361) is too white or black, skipping.
#     ⚠️ Patch 3 at (70856,55373) is too white or black, skipping.
#     ⚠️ Patch 4 at (71162,55369) is too white or black, skipping.
#     ⚠️ Patch 5 at (71142,55399) is too white or black, skipping.
#     ⚠️ Patch 6 at (71360,55411) is too white or black, skipping.
#     ⚠️ Patch 7 at (71668,55417) is too white or black, skipping.
#     ⚠️ Patch 8 at (71048,55441) is too white or black, skipping.
#     ⚠️ Patch 9 at (70697,55477) is too white or black, skipping.
#     ⚠️ Patch 10 at (71114,55483) is too white or black, skipping.
#     ⚠️ Patch 11 at (70753,55488) is too white or black, skipping.
#     ⚠️ Patch 12 at (71190,55481) is too white or black, skipping.
#     ⚠️ Patch 13 at (71541,55500) is too white or black, skipping.
#     ⚠️ Patch 14 at (71514,55499) is too white or black, skipping.
#     ⚠️ Patch 15 at (70897,55526) is too white or black, skipping.
#     ⚠️ Patch 16 at (71466,55527) is too white or black, skipping.
#     ⚠️ Patch 17 at (70595,55551) is too white or black, skipping.
#     ⚠️ Patch 18 at (71116,55561) is too white or black, skipping.
#     ⚠️ Patch 19 at (71652,55561) is too white or black, skipping.
#     ⚠️ Patch 20 at (72124,55575) is too white or black, skipping.
#     ⚠️ Patch 21 at (71476,55571) is too white or black, skipping.
#     ⚠️ Patch 22 at (72162,55571) is too white or black, skipping.
#     ⚠️ Patch 23 at (71908,55577) is too white or black, skipping.
#     ⚠️ Patch 24 at (70546,55583) is too white or black, skipping.
#     ⚠️ Patch 25 at (72012,55587) is too white or black, skipping.
#     ⚠️ Patch 26 at (71726,55601) is too white or black, skipping.
#     ⚠️ Patch 27 at (72200,55611) is too white or black, skipping.
#     ⚠️ Patch 28 at (71956,55615) is too white or black, skipping.
#     ⚠️ Patch 29 at (70566,55625) is too white or black, skipping.
#     ⚠️ Patch 30 at (71205,55643) is too white or black, skipping.
#     ⚠️ Patch 31 at (72132,55635) is too white or black, skipping.
#     ⚠️ Patch 32 at (72168,55640) is too white or black, skipping.
#     ⚠️ Patch 33 at (71724,55639) is too white or black, skipping.
#     ⚠️ Patch 34 at (70670,55647) is too white or black, skipping.
#     ⚠️ Patch 35 at (71354,55659) is too white or black, skipping.
#     ⚠️ Patch 36 at (72270,55653) is too white or black, skipping.
#     ⚠️ Patch 37 at (71794,55657) is too white or black, skipping.
#     ⚠️ Patch 38 at (71188,55663) is too white or black, skipping.
#     ⚠️ Patch 39 at (70682,55669) is too white or black, skipping.
#     ⚠️ Patch 40 at (71740,55687) is too white or black, skipping.
#     ⚠️ Patch 41 at (70404,55691) is too white or black, skipping.
#     ⚠️ Patch 42 at (72228,55695) is too white or black, skipping.
#     ⚠️ Patch 43 at (71084,55699) is too white or black, skipping.
#     ⚠️ Patch 44 at (71466,55697) is too white or black, skipping.
#     ⚠️ Patch 45 at (72094,55697) is too white or black, skipping.
#     ⚠️ Patch 46 at (72304,55707) is too white or black, skipping.
#     ⚠️ Patch 47 at (72024,55731) is too white or black, skipping.
#     ⚠️ Patch 48 at (72476,55739) is too white or black, skipping.
#     ⚠️ Patch 49 at (70792,55745) is too white or black, skipping.
#     ⚠️ Patch 50 at (72542,55747) is too white or black, skipping.
#     ⚠️ Patch 51 at (71686,55761) is too white or black, skipping.
#     ⚠️ Patch 52 at (72383,55771) is too white or black, skipping.
#     ⚠️ Patch 53 at (72110,55780) is too white or black, skipping.
#     ⚠️ Patch 54 at (71764,55781) is too white or black, skipping.
#     ⚠️ Patch 55 at (71952,55779) is too white or black, skipping.
#     ⚠️ Patch 56 at (70934,55785) is too white or black, skipping.
#     ⚠️ Patch 57 at (72350,55785) is too white or black, skipping.
#     ⚠️ Patch 58 at (72306,55789) is too white or black, skipping.
#     ⚠️ Patch 59 at (72644,55797) is too white or black, skipping.
#     ⚠️ Patch 60 at (72772,55791) is too white or black, skipping.
#     ⚠️ Patch 61 at (72086,55795) is too white or black, skipping.
#     ⚠️ Patch 62 at (72552,55804) is too white or black, skipping.
#     ⚠️ Patch 63 at (70580,55805) is too white or black, skipping.
#     ⚠️ Patch 64 at (72488,55803) is too white or black, skipping.
#     ⚠️ Patch 65 at (72371,55832) is too white or black, skipping.
#     ⚠️ Patch 66 at (70200,55829) is too white or black, skipping.
#     ⚠️ Patch 67 at (70904,55827) is too white or black, skipping.
#     ⚠️ Patch 68 at (72076,55833) is too white or black, skipping.
#     ⚠️ Patch 69 at (70160,55841) is too white or black, skipping.
#     ⚠️ Patch 70 at (72192,55855) is too white or black, skipping.
#     ⚠️ Patch 71 at (72836,55863) is too white or black, skipping.
#     ⚠️ Patch 72 at (70196,55874) is too white or black, skipping.
#     ⚠️ Patch 73 at (72890,55871) is too white or black, skipping.
#     ⚠️ Patch 74 at (70496,55875) is too white or black, skipping.
#     ⚠️ Patch 75 at (70542,55887) is too white or black, skipping.
#     ⚠️ Patch 76 at (70470,55891) is too white or black, skipping.
#     ⚠️ Patch 77 at (72728,55891) is too white or black, skipping.
#     ⚠️ Patch 78 at (70172,55897) is too white or black, skipping.
#     ⚠️ Patch 79 at (70272,55899) is too white or black, skipping.
#     ⚠️ Patch 80 at (72096,55901) is too white or black, skipping.
#     ⚠️ Patch 81 at (72800,55901) is too white or black, skipping.
#     ⚠️ Patch 82 at (72984,55899) is too white or black, skipping.
#     ⚠️ Patch 83 at (70570,55905) is too white or black, skipping.
#     ⚠️ Patch 84 at (72042,55917) is too white or black, skipping.
#     ⚠️ Patch 85 at (70458,55921) is too white or black, skipping.
#     ⚠️ Patch 86 at (71641,55929) is too white or black, skipping.
#     ⚠️ Patch 87 at (72152,55931) is too white or black, skipping.
#     ⚠️ Patch 88 at (73008,55933) is too white or black, skipping.
#     ⚠️ Patch 89 at (71590,55945) is too white or black, skipping.
#     ⚠️ Patch 90 at (72305,55952) is too white or black, skipping.
#     ⚠️ Patch 91 at (72838,55961) is too white or black, skipping.
#     ⚠️ Patch 92 at (69982,55966) is too white or black, skipping.
#     ⚠️ Patch 93 at (72058,55957) is too white or black, skipping.
#     ⚠️ Patch 94 at (70052,55965) is too white or black, skipping.
#     ⚠️ Patch 95 at (70816,55967) is too white or black, skipping.
#     ⚠️ Patch 96 at (72654,55965) is too white or black, skipping.
#     ⚠️ Patch 97 at (72904,55967) is too white or black, skipping.
#     ⚠️ Patch 98 at (70246,55971) is too white or black, skipping.
#     ⚠️ Patch 99 at (72118,55969) is too white or black, skipping.
#     ⚠️ Patch 100 at (72984,55973) is too white or black, skipping.
#     ⚠️ Patch 101 at (72416,55977) is too white or black, skipping.
#     ⚠️ Patch 102 at (71534,55987) is too white or black, skipping.
#     ⚠️ Patch 103 at (72568,55993) is too white or black, skipping.
#     ⚠️ Patch 104 at (69910,56007) is too white or black, skipping.
#     ⚠️ Patch 105 at (70056,56013) is too white or black, skipping.
#     ⚠️ Patch 106 at (71644,56011) is too white or black, skipping.
#     ⚠️ Patch 107 at (69938,56015) is too white or black, skipping.
#     ⚠️ Patch 108 at (70430,56015) is too white or black, skipping.
#     ⚠️ Patch 109 at (70616,56015) is too white or black, skipping.
#     ⚠️ Patch 110 at (72222,56015) is too white or black, skipping.
#     ⚠️ Patch 111 at (70110,56017) is too white or black, skipping.
#     ⚠️ Patch 112 at (72962,56019) is too white or black, skipping.
#     ⚠️ Patch 113 at (72994,56019) is too white or black, skipping.
#     ⚠️ Patch 114 at (72314,56021) is too white or black, skipping.
#     ⚠️ Patch 115 at (73154,56021) is too white or black, skipping.
#     ⚠️ Patch 116 at (70170,56025) is too white or black, skipping.
#     ⚠️ Patch 117 at (73008,56045) is too white or black, skipping.
#     ⚠️ Patch 118 at (70870,56049) is too white or black, skipping.
#     ⚠️ Patch 119 at (72794,56049) is too white or black, skipping.
#     ⚠️ Patch 120 at (72248,56055) is too white or black, skipping.
#     ⚠️ Patch 121 at (73210,56057) is too white or black, skipping.
#     ⚠️ Patch 122 at (71324,56067) is too white or black, skipping.
#     ⚠️ Patch 123 at (72442,56077) is too white or black, skipping.
#     ⚠️ Patch 124 at (72374,56079) is too white or black, skipping.
#     ⚠️ Patch 125 at (70030,56081) is too white or black, skipping.
#     ⚠️ Patch 126 at (70448,56083) is too white or black, skipping.
#     ⚠️ Patch 127 at (73005,56097) is too white or black, skipping.
#     ⚠️ Patch 128 at (72518,56093) is too white or black, skipping.
#     ⚠️ Patch 129 at (70625,56109) is too white or black, skipping.
#     ⚠️ Patch 130 at (70522,56113) is too white or black, skipping.
#     ⚠️ Patch 131 at (72136,56111) is too white or black, skipping.
#     ⚠️ Patch 132 at (70800,56119) is too white or black, skipping.
#     ⚠️ Patch 133 at (71132,56121) is too white or black, skipping.
#     ⚠️ Patch 134 at (72850,56123) is too white or black, skipping.
#     ⚠️ Patch 135 at (73228,56123) is too white or black, skipping.
#     ⚠️ Patch 136 at (69922,56125) is too white or black, skipping.
#     ⚠️ Patch 137 at (70070,56129) is too white or black, skipping.
#     ⚠️ Patch 138 at (69956,56149) is too white or black, skipping.
#     ⚠️ Patch 139 at (70738,56149) is too white or black, skipping.
#     ⚠️ Patch 140 at (70771,56159) is too white or black, skipping.
#     ⚠️ Patch 141 at (72138,56149) is too white or black, skipping.
#     ⚠️ Patch 142 at (73026,56149) is too white or black, skipping.
#     ⚠️ Patch 143 at (72682,56167) is too white or black, skipping.
#     ⚠️ Patch 144 at (70678,56163) is too white or black, skipping.
#     ⚠️ Patch 145 at (72396,56169) is too white or black, skipping.
#     ⚠️ Patch 146 at (72166,56169) is too white or black, skipping.
#     ⚠️ Patch 147 at (72432,56173) is too white or black, skipping.
#     ⚠️ Patch 148 at (69988,56177) is too white or black, skipping.
#     ⚠️ Patch 149 at (71010,56177) is too white or black, skipping.
#     ⚠️ Patch 150 at (72326,56179) is too white or black, skipping.
#     ⚠️ Patch 151 at (72374,56183) is too white or black, skipping.
#     ⚠️ Patch 152 at (70794,56193) is too white or black, skipping.
#     ⚠️ Patch 153 at (70870,56189) is too white or black, skipping.
#     ⚠️ Patch 154 at (72740,56193) is too white or black, skipping.
#     ⚠️ Patch 155 at (70626,56197) is too white or black, skipping.
#     ⚠️ Patch 156 at (72976,56205) is too white or black, skipping.
#     ⚠️ Patch 157 at (71172,56211) is too white or black, skipping.
#     ⚠️ Patch 158 at (69978,56213) is too white or black, skipping.
#     ⚠️ Patch 159 at (70684,56219) is too white or black, skipping.
#     ⚠️ Patch 160 at (73040,56221) is too white or black, skipping.
#     ⚠️ Patch 161 at (72328,56229) is too white or black, skipping.
#     ⚠️ Patch 162 at (72838,56239) is too white or black, skipping.
#     ⚠️ Patch 163 at (70748,56245) is too white or black, skipping.
#     ⚠️ Patch 164 at (72388,56245) is too white or black, skipping.
#     ⚠️ Patch 165 at (73004,56243) is too white or black, skipping.
#     ⚠️ Patch 166 at (72750,56245) is too white or black, skipping.
#     ⚠️ Patch 167 at (73358,56259) is too white or black, skipping.
#     ⚠️ Patch 168 at (71792,56271) is too white or black, skipping.
#     ⚠️ Patch 169 at (73458,56275) is too white or black, skipping.
#     ⚠️ Patch 170 at (70042,56283) is too white or black, skipping.
#     ⚠️ Patch 171 at (73160,56285) is too white or black, skipping.
#     ⚠️ Patch 172 at (70136,56287) is too white or black, skipping.
#     ⚠️ Patch 173 at (70820,56289) is too white or black, skipping.
#     ⚠️ Patch 174 at (73084,56299) is too white or black, skipping.
#     ⚠️ Patch 175 at (72478,56308) is too white or black, skipping.
#     ⚠️ Patch 176 at (70382,56309) is too white or black, skipping.
#     ⚠️ Patch 177 at (72630,56311) is too white or black, skipping.
#     ⚠️ Patch 178 at (70255,56318) is too white or black, skipping.
#     ⚠️ Patch 179 at (72458,56326) is too white or black, skipping.
#     ⚠️ Patch 180 at (70125,56326) is too white or black, skipping.
#     ⚠️ Patch 181 at (71834,56323) is too white or black, skipping.
#     ⚠️ Patch 182 at (73380,56325) is too white or black, skipping.
#     ⚠️ Patch 183 at (73250,56331) is too white or black, skipping.
#     ⚠️ Patch 184 at (73320,56331) is too white or black, skipping.
#     ⚠️ Patch 185 at (70333,56345) is too white or black, skipping.
#     ⚠️ Patch 186 at (70984,56339) is too white or black, skipping.
#     ⚠️ Patch 187 at (73356,56341) is too white or black, skipping.
#     ⚠️ Patch 188 at (72056,56345) is too white or black, skipping.
#     ⚠️ Patch 189 at (72010,56349) is too white or black, skipping.
#     ⚠️ Patch 190 at (72334,56359) is too white or black, skipping.
#     ⚠️ Patch 191 at (73298,56357) is too white or black, skipping.
#     ⚠️ Patch 192 at (70258,56365) is too white or black, skipping.
#     ⚠️ Patch 193 at (73124,56369) is too white or black, skipping.
#     ⚠️ Patch 194 at (72442,56369) is too white or black, skipping.
#     ⚠️ Patch 195 at (73018,56369) is too white or black, skipping.
#     ⚠️ Patch 196 at (73226,56375) is too white or black, skipping.
#     ⚠️ Patch 197 at (70266,56377) is too white or black, skipping.
# ...
#     ⚠️ Patch 65 at (26688,125264) is too white or black, skipping.
#     ⚠️ Patch 66 at (26430,125274) is too white or black, skipping.
#     ⚠️ Patch 67 at (25572,125278) is too white or black, skipping.
#     ⚠️ Patch 68 at (26014,125276) is too white or black, skipping.
#     ⚠️ Patch 69 at (26084,125276) is too white or black, skipping.
#     ⚠️ Patch 70 at (26530,125290) is too white or black, skipping.
#     ⚠️ Patch 71 at (26338,125288) is too white or black, skipping.
#     ⚠️ Patch 72 at (25546,125298) is too white or black, skipping.
#     ⚠️ Patch 73 at (26390,125298) is too white or black, skipping.
#     ⚠️ Patch 74 at (26434,125304) is too white or black, skipping.
#     ⚠️ Patch 75 at (26274,125308) is too white or black, skipping.
#     ⚠️ Patch 76 at (26334,125312) is too white or black, skipping.
#     ⚠️ Patch 77 at (26352,125322) is too white or black, skipping.
#     ⚠️ Patch 78 at (26542,125322) is too white or black, skipping.
#     ⚠️ Patch 79 at (26322,125330) is too white or black, skipping.
#     ⚠️ Patch 80 at (26282,125334) is too white or black, skipping.
#     ⚠️ Patch 81 at (26592,125342) is too white or black, skipping.
#     ⚠️ Patch 82 at (26304,125344) is too white or black, skipping.
#     ⚠️ Patch 83 at (26332,125352) is too white or black, skipping.
#     ⚠️ Patch 84 at (25734,125360) is too white or black, skipping.
#     ⚠️ Patch 85 at (26306,125362) is too white or black, skipping.
#     ⚠️ Patch 86 at (26268,125372) is too white or black, skipping.
#     ⚠️ Patch 87 at (25548,125418) is too white or black, skipping.
#     ⚠️ Patch 88 at (26236,125441) is too white or black, skipping.
#     ⚠️ Patch 89 at (25502,125454) is too white or black, skipping.
#     ⚠️ Patch 90 at (25530,125458) is too white or black, skipping.
#     ⚠️ Patch 91 at (25722,125468) is too white or black, skipping.
#     ⚠️ Patch 92 at (25964,125490) is too white or black, skipping.
#     ⚠️ Patch 93 at (25740,125496) is too white or black, skipping.
#     ⚠️ Patch 94 at (26114,125498) is too white or black, skipping.
#     ⚠️ Patch 95 at (26162,125516) is too white or black, skipping.
#     ⚠️ Patch 96 at (26482,125516) is too white or black, skipping.
#     ⚠️ Patch 97 at (25528,125526) is too white or black, skipping.
#     ⚠️ Patch 98 at (25888,125540) is too white or black, skipping.
#     ⚠️ Patch 99 at (25995,125545) is too white or black, skipping.
#     ⚠️ Patch 100 at (26154,125542) is too white or black, skipping.
#     ⚠️ Patch 101 at (26276,125598) is too white or black, skipping.
#     ⚠️ Patch 102 at (26344,125602) is too white or black, skipping.
#     ⚠️ Patch 103 at (26464,125602) is too white or black, skipping.
#     ⚠️ Patch 104 at (26222,125616) is too white or black, skipping.
#     ⚠️ Patch 105 at (26300,125620) is too white or black, skipping.
#     ⚠️ Patch 106 at (25548,125642) is too white or black, skipping.
#     ⚠️ Patch 107 at (26178,125659) is too white or black, skipping.
#     ⚠️ Patch 108 at (26405,125659) is too white or black, skipping.
#     ⚠️ Patch 109 at (26434,125677) is too white or black, skipping.
#     ⚠️ Patch 110 at (26487,125680) is too white or black, skipping.
#     ⚠️ Patch 111 at (26456,125684) is too white or black, skipping.
#     ⚠️ Patch 112 at (26422,125702) is too white or black, skipping.
#     ⚠️ Patch 113 at (25896,125726) is too white or black, skipping.
#     ⚠️ Patch 114 at (26482,125729) is too white or black, skipping.
#     ⚠️ Patch 115 at (26290,125736) is too white or black, skipping.
#     ⚠️ Patch 116 at (26404,125740) is too white or black, skipping.
#     ⚠️ Patch 117 at (25532,125743) is too white or black, skipping.
#     ⚠️ Patch 118 at (26368,125754) is too white or black, skipping.
#     ⚠️ Patch 119 at (26534,125752) is too white or black, skipping.
#     ⚠️ Patch 120 at (25952,125756) is too white or black, skipping.
#     ⚠️ Patch 121 at (26202,125756) is too white or black, skipping.
#     ⚠️ Patch 122 at (25598,125778) is too white or black, skipping.
#     ⚠️ Patch 123 at (26334,125766) is too white or black, skipping.
#     ⚠️ Patch 124 at (25568,125775) is too white or black, skipping.
#     ⚠️ Patch 125 at (25882,125770) is too white or black, skipping.
#     ⚠️ Patch 126 at (25892,125802) is too white or black, skipping.
#     ⚠️ Patch 127 at (25826,125808) is too white or black, skipping.
#     ⚠️ Patch 128 at (26500,125810) is too white or black, skipping.
#     ⚠️ Patch 129 at (25436,125818) is too white or black, skipping.
#     ⚠️ Patch 130 at (25752,125818) is too white or black, skipping.
#     ⚠️ Patch 131 at (26488,125836) is too white or black, skipping.
#     ⚠️ Patch 132 at (25412,125851) is too white or black, skipping.
#     ⚠️ Patch 133 at (25750,125840) is too white or black, skipping.
#     ⚠️ Patch 134 at (26524,125842) is too white or black, skipping.
#     ⚠️ Patch 135 at (26546,125840) is too white or black, skipping.
#     ⚠️ Patch 136 at (25444,125854) is too white or black, skipping.
#     ⚠️ Patch 137 at (25816,125858) is too white or black, skipping.
#     ⚠️ Patch 138 at (26191,125863) is too white or black, skipping.
#     ⚠️ Patch 139 at (26017,125874) is too white or black, skipping.
#     ⚠️ Patch 140 at (26525,125870) is too white or black, skipping.
#     ⚠️ Patch 141 at (26567,125872) is too white or black, skipping.
#     ⚠️ Patch 142 at (25404,125872) is too white or black, skipping.
#     ⚠️ Patch 143 at (26325,125893) is too white or black, skipping.
#     ⚠️ Patch 144 at (25642,125898) is too white or black, skipping.
#     ⚠️ Patch 145 at (26001,125902) is too white or black, skipping.
#     ⚠️ Patch 146 at (26018,125916) is too white or black, skipping.
#     ⚠️ Patch 147 at (25648,125922) is too white or black, skipping.
#     ⚠️ Patch 148 at (25682,125920) is too white or black, skipping.
#     ⚠️ Patch 149 at (25894,125926) is too white or black, skipping.
#     ⚠️ Patch 150 at (26040,125930) is too white or black, skipping.
#     ⚠️ Patch 151 at (25380,125941) is too white or black, skipping.
#     ⚠️ Patch 152 at (25770,125940) is too white or black, skipping.
#     ⚠️ Patch 153 at (25584,125951) is too white or black, skipping.
#     ⚠️ Patch 154 at (25440,125959) is too white or black, skipping.
#     ⚠️ Patch 155 at (26056,125952) is too white or black, skipping.
#     ⚠️ Patch 156 at (25420,125956) is too white or black, skipping.
#     ⚠️ Patch 157 at (25476,125971) is too white or black, skipping.
#     ⚠️ Patch 158 at (26584,125966) is too white or black, skipping.
#     ⚠️ Patch 159 at (25536,125982) is too white or black, skipping.
#     ⚠️ Patch 160 at (26168,125984) is too white or black, skipping.
#     ⚠️ Patch 161 at (25538,125998) is too white or black, skipping.
#     ⚠️ Patch 162 at (25622,125998) is too white or black, skipping.
#     ⚠️ Patch 163 at (25594,126006) is too white or black, skipping.
#     ⚠️ Patch 164 at (25688,126010) is too white or black, skipping.
#     ⚠️ Patch 165 at (26326,126006) is too white or black, skipping.
#     ⚠️ Patch 166 at (25504,126017) is too white or black, skipping.
#     ⚠️ Patch 167 at (26122,126024) is too white or black, skipping.
#     ⚠️ Patch 168 at (25544,126026) is too white or black, skipping.
#     ⚠️ Patch 169 at (25838,126028) is too white or black, skipping.
#     ⚠️ Patch 170 at (26352,126082) is too white or black, skipping.
#     ⚠️ Patch 171 at (25850,126098) is too white or black, skipping.
#     ⚠️ Patch 172 at (25788,126110) is too white or black, skipping.
#     ⚠️ Patch 173 at (25960,126156) is too white or black, skipping.
#     ⚠️ Patch 174 at (26107,126171) is too white or black, skipping.
#     ⚠️ Patch 175 at (34236,123740) is too white or black, skipping.
#     ⚠️ Patch 176 at (34360,123750) is too white or black, skipping.
#     ⚠️ Patch 177 at (34990,124038) is too white or black, skipping.
#     ⚠️ Patch 178 at (34706,124044) is too white or black, skipping.
#     ⚠️ Patch 179 at (34608,124236) is too white or black, skipping.
#     ⚠️ Patch 180 at (35098,124264) is too white or black, skipping.
#     ⚠️ Patch 181 at (34004,124350) is too white or black, skipping.
#     ⚠️ Patch 182 at (34834,124468) is too white or black, skipping.
#     ⚠️ Patch 183 at (33791,124756) is too white or black, skipping.
#     ⚠️ Patch 184 at (34484,124788) is too white or black, skipping.
#     ⚠️ Patch 185 at (34506,124786) is too white or black, skipping.
#     ⚠️ Patch 186 at (35750,124794) is too white or black, skipping.
#     ⚠️ Patch 187 at (34586,124828) is too white or black, skipping.
#     ⚠️ Patch 188 at (34856,124872) is too white or black, skipping.
#     ⚠️ Patch 189 at (34226,124968) is too white or black, skipping.
#     ⚠️ Patch 190 at (33608,125010) is too white or black, skipping.
#     ⚠️ Patch 191 at (34472,125060) is too white or black, skipping.
#     ⚠️ Patch 192 at (35094,125080) is too white or black, skipping.
#     ⚠️ Patch 193 at (33694,125118) is too white or black, skipping.
#     ⚠️ Patch 194 at (34502,125134) is too white or black, skipping.
#     ⚠️ Patch 195 at (33896,125196) is too white or black, skipping.
#     ⚠️ Patch 196 at (34104,125218) is too white or black, skipping.
#     ⚠️ Patch 197 at (35391,125234) is too white or black, skipping.
#     ⚠️ Patch 198 at (33858,125242) is too white or black, skipping.
#     ⚠️ Patch 199 at (34442,125260) is too white or black, skipping.
#     ⚠️ Patch 200 at (35416,125270) is too white or black, skipping.
#     ⚠️ Patch 201 at (33444,125268) is too white or black, skipping.
#     ⚠️ Patch 202 at (34974,125294) is too white or black, skipping.
#     ⚠️ Patch 203 at (34480,125290) is too white or black, skipping.
#     ⚠️ Patch 204 at (35828,125300) is too white or black, skipping.
#     ⚠️ Patch 205 at (35162,125314) is too white or black, skipping.
#     ⚠️ Patch 206 at (34454,125318) is too white or black, skipping.
#     ⚠️ Patch 207 at (35285,125339) is too white or black, skipping.
#     ⚠️ Patch 208 at (33452,125338) is too white or black, skipping.
#     ⚠️ Patch 209 at (35186,125334) is too white or black, skipping.
#     ⚠️ Patch 210 at (35126,125342) is too white or black, skipping.
#     ⚠️ Patch 211 at (34354,125348) is too white or black, skipping.
#     ⚠️ Patch 212 at (35148,125348) is too white or black, skipping.
#     ⚠️ Patch 213 at (34418,125386) is too white or black, skipping.
#     ⚠️ Patch 214 at (34342,125400) is too white or black, skipping.
#     ⚠️ Patch 215 at (33970,125458) is too white or black, skipping.
#     ⚠️ Patch 216 at (34126,125460) is too white or black, skipping.
#     ⚠️ Patch 217 at (35221,125457) is too white or black, skipping.
#     ⚠️ Patch 218 at (33754,125494) is too white or black, skipping.
#     ⚠️ Patch 219 at (33268,125500) is too white or black, skipping.
#     ⚠️ Patch 220 at (35205,125565) is too white or black, skipping.
#     ⚠️ Patch 221 at (33690,125562) is too white or black, skipping.
#     ⚠️ Patch 222 at (35324,125573) is too white or black, skipping.
#     ⚠️ Patch 223 at (33774,125570) is too white or black, skipping.
#     ⚠️ Patch 224 at (34052,125574) is too white or black, skipping.
#     ⚠️ Patch 225 at (33798,125574) is too white or black, skipping.
#     ⚠️ Patch 226 at (35625,125573) is too white or black, skipping.
#     ⚠️ Patch 227 at (33856,125592) is too white or black, skipping.
#     ⚠️ Patch 228 at (33814,125596) is too white or black, skipping.
#     ⚠️ Patch 229 at (35232,125606) is too white or black, skipping.
#     ⚠️ Patch 230 at (33406,125622) is too white or black, skipping.
#     ⚠️ Patch 231 at (34018,125646) is too white or black, skipping.
#     ⚠️ Patch 232 at (33815,125709) is too white or black, skipping.
#     ⚠️ Patch 233 at (33669,125734) is too white or black, skipping.
#     ⚠️ Patch 234 at (33617,125746) is too white or black, skipping.
#     ⚠️ Patch 235 at (33304,125748) is too white or black, skipping.
#     ⚠️ Patch 236 at (34202,125746) is too white or black, skipping.
#     ⚠️ Patch 237 at (33342,125780) is too white or black, skipping.
#     ⚠️ Patch 238 at (33882,125778) is too white or black, skipping.
#     ⚠️ Patch 239 at (33408,125812) is too white or black, skipping.
#     ⚠️ Patch 240 at (34118,125842) is too white or black, skipping.
#     ⚠️ Patch 241 at (34180,125844) is too white or black, skipping.
#     ⚠️ Patch 242 at (35389,125875) is too white or black, skipping.
#     ⚠️ Patch 243 at (34186,125890) is too white or black, skipping.
#     ⚠️ Patch 244 at (34018,125898) is too white or black, skipping.
#     ⚠️ Patch 245 at (34080,125936) is too white or black, skipping.
#     ⚠️ Patch 246 at (33990,125984) is too white or black, skipping.
#     ⚠️ Patch 247 at (34258,126000) is too white or black, skipping.
#     ⚠️ Patch 248 at (34114,126010) is too white or black, skipping.
#     ⚠️ Patch 249 at (33508,125306) is too white or black, skipping.
#     ⚠️ Patch 250 at (33330,125684) is too white or black, skipping.
#     ⚠️ Patch 251 at (33669,125685) is too white or black, skipping.
#     ⚠️ Patch 252 at (33705,125702) is too white or black, skipping.
#     ⚠️ Patch 253 at (33662,125540) is too white or black, skipping.
#     ⚠️ Patch 254 at (33964,125382) is too white or black, skipping.
#     ⚠️ Patch 255 at (33949,125490) is too white or black, skipping.
#     ⚠️ Patch 256 at (33890,125619) is too white or black, skipping.
#     ⚠️ Patch 257 at (33787,125819) is too white or black, skipping.
#     ⚠️ Patch 258 at (34152,125466) is too white or black, skipping.
#     ⚠️ Patch 259 at (34073,125554) is too white or black, skipping.
#     ⚠️ Patch 260 at (34237,125244) is too white or black, skipping.
#     ⚠️ Patch 261 at (33646,124533) is too white or black, skipping.
#     ⚠️ Patch 262 at (34082,125599) is too white or black, skipping.
#     ⚠️ Patch 263 at (34049,125881) is too white or black, skipping.
#     ⚠️ Patch 264 at (34049,125945) is too white or black, skipping.
#     ⚠️ Patch 265 at (34036,125896) is too white or black, skipping.
#     ⚠️ Patch 266 at (33985,125914) is too white or black, skipping.
#     ⚠️ Patch 267 at (33913,125911) is too white or black, skipping.
#     ⚠️ Patch 268 at (34097,125966) is too white or black, skipping.
#     ⚠️ Patch 269 at (34419,126058) is too white or black, skipping.
#     ⚠️ Patch 270 at (34506,125269) is too white or black, skipping.
#     ⚠️ Patch 271 at (34971,126032) is too white or black, skipping.
#     ⚠️ Patch 272 at (35453,125598) is too white or black, skipping.
#     ⚠️ Patch 273 at (35504,125579) is too white or black, skipping.
#     ⚠️ Patch 274 at (35215,125372) is too white or black, skipping.
#     ⚠️ Patch 275 at (35284,124898) is too white or black, skipping.
#     ⚠️ Patch 276 at (34860,124827) is too white or black, skipping.
#     ⚠️ Patch 277 at (34560,124731) is too white or black, skipping.
#     ⚠️ Patch 278 at (34481,124815) is too white or black, skipping.
#     ⚠️ Patch 279 at (34497,124822) is too white or black, skipping.
#     ⚠️ Patch 280 at (34457,124842) is too white or black, skipping.
#     ⚠️ Patch 281 at (34488,124851) is too white or black, skipping.
#     ⚠️ Patch 282 at (34487,124889) is too white or black, skipping.
#     ⚠️ Patch 283 at (34040,124657) is too white or black, skipping.
#     ⚠️ Patch 284 at (33988,124780) is too white or black, skipping.
#     ⚠️ Patch 285 at (34058,124428) is too white or black, skipping.
#     ⚠️ Patch 286 at (33483,124657) is too white or black, skipping.
#     ⚠️ Patch 287 at (33635,125017) is too white or black, skipping.
#     ⚠️ Patch 288 at (33561,125014) is too white or black, skipping.
#     ⚠️ Patch 289 at (33899,124297) is too white or black, skipping.
#     ⚠️ Patch 290 at (33875,124274) is too white or black, skipping.
#     ⚠️ Patch 291 at (33807,124168) is too white or black, skipping.
#     ⚠️ Patch 292 at (33875,124372) is too white or black, skipping.
#     ⚠️ Patch 293 at (34534,123819) is too white or black, skipping.
#     ⚠️ Patch 294 at (34672,124243) is too white or black, skipping.
#     ⚠️ Patch 295 at (34483,124298) is too white or black, skipping.
#     ⚠️ Patch 296 at (34504,124319) is too white or black, skipping.
#     ⚠️ Patch 297 at (34279,124371) is too white or black, skipping.
#     ⚠️ Patch 298 at (34741,124624) is too white or black, skipping.
#     ⚠️ Patch 299 at (34949,124680) is too white or black, skipping.
#
# ✅ Patch extraction complete.

# %% [markdown]
# # Extracting patches from ROIs from the test dirs

# %%
# Configuration
PATCH_SIZE = 256
NUM_PATCHES_PER_FILE = 5

# Paths
#happiny_folder = Path("/data/temporary/archives/lung/generator/MONKEY_challenge")
#json_pixel_dir = happiny_folder / "annotations/json_pix"
PATCHES_DIR = happiny_folder / "patches_test"

cpg_dir = happiny_folder / "images/pas-cpg"

# Create output directories for cpg modalities + cell types
for cell_type in ["inflammatory-cells", "lymphocytes", "monocytes"]:
    (PATCHES_DIR / "cpg" / cell_type).mkdir(parents=True, exist_ok=True)

# Helpers
def get_sample_id(json_path):
    match = re.search(r'P\d{6}', json_path.name)
    return match.group(0) if match else None

def load_json_annotations(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
    return [(int(p["point"][0]), int(p["point"][1])) for p in data.get("points", [])]

def extract_patch(tif_path, center_x, center_y, patch_size=PATCH_SIZE):
    half = patch_size // 2
    xmin = max(center_x - half, 0)
    ymin = max(center_y - half, 0)
    with rasterio.open(tif_path) as src:
        max_width, max_height = src.width, src.height
        xmin = min(xmin, max_width - patch_size)
        ymin = min(ymin, max_height - patch_size)
        window = Window(xmin, ymin, patch_size, patch_size)
        patch = src.read(window=window)
        patch = np.transpose(patch, (1, 2, 0))  # (H, W, C)
    return patch

def save_cpg_patches_for_cell_types():
    # Cell types to process
    cell_types = ["inflammatory-cells", "lymphocytes", "monocytes"]
    
    # For each cell type, find relevant json files
    for cell_type in cell_types:
        json_files = sorted(json_pixel_dir.glob(f"*{cell_type}.json"))
        print(f"Found {len(json_files)} {cell_type} JSON files")

        for json_file in json_files:
            coords = load_json_annotations(json_file)[:NUM_PATCHES_PER_FILE]
            sample_id = get_sample_id(json_file)
            if not sample_id:
                continue

            tif_matches = list(cpg_dir.glob(f"*{sample_id}*.tif"))
            if not tif_matches:
                continue

            tif_path = tif_matches[0]  # Use the first match
            print(f"Processing {tif_path.name} with {len(coords)} {cell_type} ROIs")

            output_dir = PATCHES_DIR / "cpg" / cell_type

            for i, (x, y) in enumerate(coords):
                patch = extract_patch(tif_path, x, y, PATCH_SIZE)
                patch_img = Image.fromarray(patch.astype(np.uint8))
                patch_name = f"{sample_id}_{cell_type}_patch{i}.png"
                patch_img.save(output_dir / patch_name)

if __name__ == "__main__":
    save_cpg_patches_for_cell_types()
    print("✅ Finished extracting cpg patches for inflammatory, lymphocytes, and monocytes.")
# Out:
# Found 81 inflammatory-cells JSON files
# Processing B_P000001_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000002_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000003_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000004_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000005_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000006_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000007_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000011_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000014_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000016_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000017_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000018_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000020_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000021_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000022_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000024_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000029_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000030_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000031_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000032_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000033_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000034_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000035_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000036_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000037_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000038_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000001_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000002_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000003_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000004_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000005_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000007_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000009_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000010_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000011_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000012_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000013_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000014_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000015_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000016_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000017_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000019_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000020_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000021_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000022_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000023_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000024_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000025_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000026_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000027_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000028_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000029_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000030_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000031_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000032_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000033_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000034_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000035_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000036_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000037_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000038_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000039_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing C_P000040_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000001_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000002_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000003_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000004_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000005_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000006_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000007_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000009_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000010_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000011_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000012_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000013_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000014_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing B_P000015_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000016_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000017_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing A_P000018_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Processing D_P000019_PAS_CPG.tif with 5 inflammatory-cells ROIs
# Found 81 lymphocytes JSON files
# Processing B_P000001_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000002_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000003_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000004_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000005_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000006_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000007_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000011_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000014_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000016_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000017_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000018_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000020_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000021_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000022_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000024_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000029_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000030_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000031_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000032_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000033_PAS_CPG.tif with 4 lymphocytes ROIs
# Processing C_P000034_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000035_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000036_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000037_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000038_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000001_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000002_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000003_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000004_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000005_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000007_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000009_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000010_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000011_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000012_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000013_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000014_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000015_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000016_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000017_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000019_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000020_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000021_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000022_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000023_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000024_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000025_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000026_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000027_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000028_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000029_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000030_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000031_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000032_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000033_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000034_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000035_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000036_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000037_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000038_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000039_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing C_P000040_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000001_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000002_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000003_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000004_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000005_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000006_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000007_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000009_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000010_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000011_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000012_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000013_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000014_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing B_P000015_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000016_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000017_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing A_P000018_PAS_CPG.tif with 5 lymphocytes ROIs
# Processing D_P000019_PAS_CPG.tif with 5 lymphocytes ROIs
# Found 81 monocytes JSON files
# Processing B_P000001_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000002_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000003_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000004_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000005_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000006_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000007_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000011_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000014_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000016_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000017_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000018_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000020_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000021_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000022_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000024_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000029_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000030_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000031_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000032_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000033_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000034_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000035_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000036_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000037_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000038_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000001_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000002_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000003_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000004_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000005_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000007_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000009_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000010_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000011_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000012_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000013_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000014_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000015_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000016_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000017_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000019_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000020_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000021_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000022_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000023_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000024_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000025_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000026_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000027_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000028_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000029_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000030_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000031_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000032_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000033_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000034_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000035_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000036_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000037_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000038_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000039_PAS_CPG.tif with 5 monocytes ROIs
# Processing C_P000040_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000001_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000002_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000003_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000004_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000005_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000006_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000007_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000009_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000010_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000011_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000012_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000013_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000014_PAS_CPG.tif with 5 monocytes ROIs
# Processing B_P000015_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000016_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000017_PAS_CPG.tif with 5 monocytes ROIs
# Processing A_P000018_PAS_CPG.tif with 5 monocytes ROIs
# Processing D_P000019_PAS_CPG.tif with 5 monocytes ROIs
# ✅ Finished extracting cpg patches for inflammatory, lymphocytes, and monocytes.

# %% [markdown]
# # Model building

# %%
train_dirs = [
    PATCHES_DIR / "pas-original",
    PATCHES_DIR / "pas-diagnostic"
]
test_dirs = [
    PATCHES_DIR / "cpg" / "inflammatory-cells",
    PATCHES_DIR / "cpg" / "monocytes",
    PATCHES_DIR / "cpg" / "lymphocytes"
]
cpg_inflammatory_dir = PATCHES_DIR / "cpg" / "inflammatory-cells"

class_names_all = ["inflammatory-cells", "monocytes", "lymphocytes"]

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

def wrap_with_label_folder(path, label="dummy"):
    temp = path.parent / f"{path.name}_wrapped"
    temp.mkdir(exist_ok=True)
    label_path = temp / label
    label_path.mkdir(exist_ok=True)
    for img in path.glob("*.png"):
        symlink = label_path / img.name
        if not symlink.exists():
            symlink.symlink_to(img)
    return temp

# Create dataloaders from directories
def create_dataloader(dirs, transform, batch_size=32, shuffle=True):
    wrapped_dirs = [wrap_with_label_folder(d) for d in dirs]
    datasets_list = [datasets.ImageFolder(d, transform=transform) for d in wrapped_dirs]
    combined_dataset = ConcatDataset(datasets_list)
    loader = DataLoader(combined_dataset, batch_size=batch_size, shuffle=shuffle)
    return loader

# Extract features for a given dataset loader and encoder model
def extract_features(encoder, loader, device):
    encoder.eval()
    all_feats = []
    all_labels = []
    with torch.no_grad():
        for imgs, labels in loader:
            imgs = imgs.to(device)
            feats = encoder(imgs).cpu()
            all_feats.append(feats)
            all_labels.append(labels)
    X = torch.cat(all_feats).numpy()
    y = torch.cat(all_labels).numpy()
    return X, y

# Pretrain encoder on train_dirs (pas-original + pas-diagnostic)
def pretrain_encoder(train_dirs, transform, device, epochs=5):
    train_loader = create_dataloader(train_dirs, transform, batch_size=32, shuffle=True)
    encoder = models.resnet18(pretrained=True)
    encoder.fc = nn.Identity()  
    encoder = encoder.to(device)
    optimizer = optim.Adam(encoder.parameters(), lr=1e-4)
    encoder.train()
    for epoch in range(epochs):
        for imgs, _ in tqdm(train_loader, desc=f"Pretraining Epoch {epoch+1}"):
            imgs = imgs.to(device)
            features = encoder(imgs)
            loss = features.norm(dim=1).mean() 
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    return encoder

# Fine-tune encoder on only CPG inflammatory-cells (binary classification)
def finetune_on_cpg_inflammatory(encoder, cpg_dir, transform, device, epochs=3):
    # Prepare dataset with label 0 for inflammatory cells (binary classification)
    wrapped_dir = wrap_with_label_folder(cpg_dir, label="inflammatory-cells")
    dataset = datasets.ImageFolder(wrapped_dir, transform=transform)
    loader = DataLoader(dataset, batch_size=32, shuffle=True)
    
    # Add classification head for binary classification
    encoder.fc = nn.Linear(512, 2)
    encoder = encoder.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(encoder.parameters(), lr=1e-4)
    
    encoder.train()
    for epoch in range(epochs):
        for imgs, labels in tqdm(loader, desc=f"Fine-tuning CPG inflammatory Epoch {epoch+1}"):
            imgs, labels = imgs.to(device), labels.to(device)
            outputs = encoder(imgs)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
    return encoder

# Prepare test dataloader for all CPG classes with correct labels
def create_cpg_test_loader(test_dirs, transform, batch_size=32):
    wrapped_dirs = []
    for i, d in enumerate(test_dirs):
        wrapped_dirs.append(wrap_with_label_folder(d, label=str(i)))  # label folder name = class index
    datasets_list = [datasets.ImageFolder(d, transform=transform) for d in wrapped_dirs]
    combined_dataset = ConcatDataset(datasets_list)
    loader = DataLoader(combined_dataset, batch_size=batch_size, shuffle=False)
    return loader

# Extract features with fine-tuned encoder for multi-class classification
def extract_features_multiclass(encoder, loader, device):
    encoder.eval()
    all_feats = []
    all_labels = []
    with torch.no_grad():
        for imgs, labels in loader:
            imgs = imgs.to(device)
            labels = labels.to(device)
            feats = encoder(imgs)
            all_feats.append(feats.cpu())
            all_labels.append(labels.cpu())
    X = torch.cat(all_feats).numpy()
    y = torch.cat(all_labels).numpy()
    return X, y

# %%
# --------- MAIN PIPELINE ---------

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Model A: Pretrain encoder on pas-original + pas-diagnostic only
print("Pretraining encoder (Model A)...")
encoder_A = pretrain_encoder(train_dirs, transform, device)

# Test Model A on all CPG classes with RF classifier on frozen encoder features
print("\nEvaluating Model A (no fine-tuning on CPG)...")
cpg_test_loader = create_cpg_test_loader(test_dirs, transform, batch_size=32)
X_A, y_A = extract_features(encoder_A, cpg_test_loader, device)

clf_A = RandomForestClassifier(n_estimators=100, random_state=42)
clf_A.fit(X_A, y_A)
y_pred_A = clf_A.predict(X_A)

print("Model A Confusion Matrix:")
print(confusion_matrix(y_A, y_pred_A))
print("Model A Classification Report:")
print(classification_report(y_A, y_pred_A, target_names=class_names_all))
# Out:
# Pretraining encoder (Model A)...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 7
#       5 # Model A: Pretrain encoder on pas-original + pas-diagnostic only
#       6 print("Pretraining encoder (Model A)...")
# ----> 7 encoder_A = pretrain_encoder(train_dirs, transform, device)
#       9 # Test Model A on all CPG classes with RF classifier on frozen encoder features
#      10 print("\nEvaluating Model A (no fine-tuning on CPG)...")
#
# Cell In[6], line 57, in pretrain_encoder(train_dirs, transform, device, epochs)
#      56 def pretrain_encoder(train_dirs, transform, device, epochs=5):
# ---> 57     train_loader = create_dataloader(train_dirs, transform, batch_size=32, shuffle=True)
#      58     encoder = models.resnet18(pretrained=True)
#      59     encoder.fc = nn.Identity()
#
# Cell In[6], line 34, in create_dataloader(dirs, transform, batch_size, shuffle)
#      33 def create_dataloader(dirs, transform, batch_size=32, shuffle=True):
# ---> 34     wrapped_dirs = [wrap_with_label_folder(d) for d in dirs]
#      35     datasets_list = [datasets.ImageFolder(d, transform=transform) for d in wrapped_dirs]
#      36     combined_dataset = ConcatDataset(datasets_list)
#
# Cell In[6], line 29, in wrap_with_label_folder(path, label)
#      27     symlink = label_path / img.name
#      28     if not symlink.exists():
# ---> 29         symlink.symlink_to(img)
#      30 return temp
#
# File c:\Users\luukn\AppData\Local\Programs\Python\Python312\Lib\pathlib.py:1387, in Path.symlink_to(self, target, target_is_directory)
#    1385 if not hasattr(os, "symlink"):
#    1386     raise NotImplementedError("os.symlink() not available on this system")
# -> 1387 os.symlink(target, self, target_is_directory)
#
# OSError: [WinError 1314] A required privilege is not held by the client: 'C:\\Users\\luukn\\AIMI_MONKEY2\\monkey-training\\patches\\pas-original\\P000001_patch0.png' -> 'C:\\Users\\luukn\\AIMI_MONKEY2\\monkey-training\\patches\\pas-original_wrapped\\dummy\\P000001_patch0.png'

# %%
# Model B: Fine-tune encoder on CPG inflammatory-cells (binary) 
print("\nFine-tuning encoder on CPG inflammatory-cells (Model B)...")
encoder_B = finetune_on_cpg_inflammatory(encoder_A, cpg_inflammatory_dir, transform, device, epochs=3)

# For Model B testing, remove classification head for feature extraction (to get embeddings)
encoder_B.fc = nn.Identity()
encoder_B = encoder_B.to(device)

# Extract features from all CPG classes with fine-tuned encoder
print("\nEvaluating Model B (fine-tuned on CPG inflammatory-cells)...")
X_B, y_B = extract_features(encoder_B, cpg_test_loader, device)

clf_B = RandomForestClassifier(n_estimators=100, random_state=42)
clf_B.fit(X_B, y_B)
y_pred_B = clf_B.predict(X_B)

print("Model B Confusion Matrix:")
print(confusion_matrix(y_B, y_pred_B))
print("Model B Classification Report:")
print(classification_report(y_B, y_pred_B, target_names=class_names_all))
